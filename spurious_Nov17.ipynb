# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

# %% [markdown]
# ## Download data
# *Icecream sales and temp*
# https://www.kaggle.com/datasets/sakshisatre/ice-cream-sales-dataset
#
# * *
