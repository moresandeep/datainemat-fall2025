# %% [markdown]
# # APIs and Endpoints — Bluesky

# %% [markdown]
# ## 0. Prerequisites
#
# ```bash
# # in your environment (Anaconda prompt or terminal)
# pip install requests
# ```

# %%
import requests
import pandas as pd
import json as js

BASE_URL = "https://api.bsky.app/xrpc"

# %%
endpoint = f"{BASE_URL}/app.bsky.feed.searchPosts"
headers = {"User-Agent": "EMAT-Teaching/1.0 (+contact@example.com)"}
params = {
    "q": "data science",
    "limit": 10,  # start small for demos
}

# %%
resp = requests.get(endpoint, params=params, headers=headers, timeout=30)

print("Status:", resp.status_code)

data = resp.json() if resp.headers.get("content-type", "").startswith("application/json") else {}

print("Top-level keys:", list(data.keys()))

print(js.dumps(data, indent=2))
# Out:
# Status: 200
# Top-level keys: ['posts', 'cursor']
# {
#   "posts": [
#     {
#       "uri": "at://did:plc:o2zm5fhfhy266cff4hosesqw/app.bsky.feed.post/3lz2el2bnrs24",
#       "cid": "bafyreif2td446x7ikz2fbk5skqrni6s3wesju4tanl5nqgpdozwt7xkyvq",
#       "author": {
#         "did": "did:plc:o2zm5fhfhy266cff4hosesqw",
#         "handle": "nabsiddiqui.bsky.social",
#         "displayName": "Nabeel Siddiqui",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:o2zm5fhfhy266cff4hosesqw/bafkreignohhlahlcscss7xyfssoskcvnpqgmslfg5jx5duwimsmxhvqvny@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [
#           {
#             "src": "did:plc:o2zm5fhfhy266cff4hosesqw",
#             "uri": "at://did:plc:o2zm5fhfhy266cff4hosesqw/app.bsky.actor.profile/self",
#             "cid": "bafyreiehqvqgpscxsds2rwgj435zfnja53sf5lomcsg4cjz5usnczh6kqa",
#             "val": "!no-unauthenticated",
#             "cts": "2024-11-13T15:57:22.793Z"
#           }
#         ],
#         "createdAt": "2024-11-13T15:54:30.580Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T17:33:20.603Z",
#         "embed": {
#           "$type": "app.bsky.embed.images",
#           "images": [
#             {
#               "alt": "",
#               "aspectRatio": {
#                 "height": 1643,
#                 "width": 2000
#               },
#               "image": {
#                 "$type": "blob",
#                 "ref": {
#                   "$link": "bafkreihw3hg4ojllkebcjcqubvnzjz3rm5yyjpr2lslgw3wcqoyaulx3zq"
#                 },
#                 "mimeType": "image/jpeg",
#                 "size": 912585
#               }
#             }
#           ]
#         },
#         "facets": [
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#link",
#                 "uri": "https://link.springer.com/book/10.1007/978-3-031-96618-7"
#               }
#             ],
#             "index": {
#               "byteEnd": 253,
#               "byteStart": 220
#             }
#           },
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "tidyverse"
#               }
#             ],
#             "index": {
#               "byteEnd": 265,
#               "byteStart": 255
#             }
#           },
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "rstats"
#               }
#             ],
#             "index": {
#               "byteEnd": 273,
#               "byteStart": 266
#             }
#           },
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "digitalhumanities"
#               }
#             ],
#             "index": {
#               "byteEnd": 292,
#               "byteStart": 274
#             }
#           }
#         ],
#         "langs": [
#           "en"
#         ],
#         "text": "My book Cultural Analytics in R: A Tidy Approach has just been published! It showcases how tidy data can be used in cultural analytics workflows, from text analysis, machine learning, network science, etc. Check it out: link.springer.com/book/10.1007...\n\n#tidyverse #rstats #digitalhumanities"
#       },
#       "embed": {
#         "$type": "app.bsky.embed.images#view",
#         "images": [
#           {
#             "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:o2zm5fhfhy266cff4hosesqw/bafkreihw3hg4ojllkebcjcqubvnzjz3rm5yyjpr2lslgw3wcqoyaulx3zq@jpeg",
#             "fullsize": "https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:o2zm5fhfhy266cff4hosesqw/bafkreihw3hg4ojllkebcjcqubvnzjz3rm5yyjpr2lslgw3wcqoyaulx3zq@jpeg",
#             "alt": "",
#             "aspectRatio": {
#               "height": 1643,
#               "width": 2000
#             }
#           }
#         ]
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 0,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T17:33:29.504Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:yqwjmsbwzo7rezbf7kmtb5ju/app.bsky.feed.post/3lz2dttlsx22g",
#       "cid": "bafyreichhhrjgnjqcao6ptc7agvvksolbphqpqpnfuwc4iqzjdekbys254",
#       "author": {
#         "did": "did:plc:yqwjmsbwzo7rezbf7kmtb5ju",
#         "handle": "cs.ubc.ca",
#         "displayName": "UBC Computer Science",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:yqwjmsbwzo7rezbf7kmtb5ju/bafkreidupnkndh7n6is6qqv6bai4bsrtluiwwwsbguj4rmdigyr3mam4dy@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2023-11-29T18:34:46.400Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T17:20:22.142Z",
#         "embed": {
#           "$type": "app.bsky.embed.images",
#           "images": [
#             {
#               "alt": "UBC Computer Science Distinguished Lecture Series. Fred Kaiser Building (2332 Main Mall, UBC), Room 2020/2030. \n\nAll lectures are free and open to the public. \n\nJ. Ross Mitchell, University of Alberta \nTalk Date:  September 25, 2025 ; 3:30 PM - 5:00 PM PST \nTitle:  Generative AI in Healthcare\n\nJohn Stamper, Carnegie Mellon University \nTalk Date:  October 9, 2025 ; 3:30 PM - 5:00 PM PST \nTitle:  What is the role of Data Science in the era of Generative AI?\n\nKimberly Keeton, Google\nTalk Date:  November 6, 2025; 3:30 PM - 5:00 PM PST \nTitle:  Not Your Grandparents' Memory System\n\nGuy E. Blelloch, Carnegie Mellon University\nTalk Date:  November 20, 2025 ; 3:30 PM - 5:00 PM PST \nTitle:  Parallel Algorithms : A Retrospective and current directions\n\nwww.cs.ubc.ca/DLS",
#               "aspectRatio": {
#                 "height": 1350,
#                 "width": 1080
#               },
#               "image": {
#                 "$type": "blob",
#                 "ref": {
#                   "$link": "bafkreidptqv7hjwykrsw5zvaosvgy2hbbcivu57mrlpcubixwollbuqlve"
#                 },
#                 "mimeType": "image/jpeg",
#                 "size": 883455
#               }
#             }
#           ]
#         },
#         "facets": [
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#link",
#                 "uri": "http://cs.ubc.ca/DLS"
#               }
#             ],
#             "index": {
#               "byteEnd": 263,
#               "byteStart": 250
#             }
#           }
#         ],
#         "langs": [
#           "en"
#         ],
#         "text": "The Distinguished Lecture Series is back! Learn about topics such as generative AI in healthcare, how data can inform AI for education, and the past and future of parallel algorithms. Lectures are free to attend and open to the public. Learn more at cs.ubc.ca/DLS"
#       },
#       "embed": {
#         "$type": "app.bsky.embed.images#view",
#         "images": [
#           {
#             "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:yqwjmsbwzo7rezbf7kmtb5ju/bafkreidptqv7hjwykrsw5zvaosvgy2hbbcivu57mrlpcubixwollbuqlve@jpeg",
#             "fullsize": "https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:yqwjmsbwzo7rezbf7kmtb5ju/bafkreidptqv7hjwykrsw5zvaosvgy2hbbcivu57mrlpcubixwollbuqlve@jpeg",
#             "alt": "UBC Computer Science Distinguished Lecture Series. Fred Kaiser Building (2332 Main Mall, UBC), Room 2020/2030. \n\nAll lectures are free and open to the public. \n\nJ. Ross Mitchell, University of Alberta \nTalk Date:  September 25, 2025 ; 3:30 PM - 5:00 PM PST \nTitle:  Generative AI in Healthcare\n\nJohn Stamper, Carnegie Mellon University \nTalk Date:  October 9, 2025 ; 3:30 PM - 5:00 PM PST \nTitle:  What is the role of Data Science in the era of Generative AI?\n\nKimberly Keeton, Google\nTalk Date:  November 6, 2025; 3:30 PM - 5:00 PM PST \nTitle:  Not Your Grandparents' Memory System\n\nGuy E. Blelloch, Carnegie Mellon University\nTalk Date:  November 20, 2025 ; 3:30 PM - 5:00 PM PST \nTitle:  Parallel Algorithms : A Retrospective and current directions\n\nwww.cs.ubc.ca/DLS",
#             "aspectRatio": {
#               "height": 1350,
#               "width": 1080
#             }
#           }
#         ]
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 0,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T17:20:24.806Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:hod2pn5qnwh3ww7n4sptrzh6/app.bsky.feed.post/3lz2dhftm7k2s",
#       "cid": "bafyreiby2bomx222s3kst2ttbzw25dd3ieeqirjgwvrnbvbxeljylp3roa",
#       "author": {
#         "did": "did:plc:hod2pn5qnwh3ww7n4sptrzh6",
#         "handle": "mad4data.bsky.social",
#         "displayName": "Madison",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:hod2pn5qnwh3ww7n4sptrzh6/bafkreia3lrg6lce7xdjwhdgqufimfhdlootm7wif3ttf7zjwsjfug5dyy4@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2024-11-20T21:13:39.596Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T17:13:25.065Z",
#         "embed": {
#           "$type": "app.bsky.embed.images",
#           "images": [
#             {
#               "alt": "",
#               "aspectRatio": {
#                 "height": 2000,
#                 "width": 1500
#               },
#               "image": {
#                 "$type": "blob",
#                 "ref": {
#                   "$link": "bafkreih2a7ktohutgzans3h6zqq5gj2vfjhrd7zn6kev375kzciq57mz64"
#                 },
#                 "mimeType": "image/jpeg",
#                 "size": 440657
#               }
#             }
#           ]
#         },
#         "facets": [
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "positconf2025"
#               }
#             ],
#             "index": {
#               "byteEnd": 33,
#               "byteStart": 19
#             }
#           },
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "publichealth"
#               }
#             ],
#             "index": {
#               "byteEnd": 258,
#               "byteStart": 245
#             }
#           }
#         ],
#         "langs": [
#           "en"
#         ],
#         "text": "Happy first day of #positconf2025 to those who celebrate! So far I\u2019ve practiced using scikit-learn, learned about how Positron fits into the progression of data science, heard about critical AI workflow tools and techniques, and co-hosted the #publichealth birds of a feather table!"
#       },
#       "embed": {
#         "$type": "app.bsky.embed.images#view",
#         "images": [
#           {
#             "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:hod2pn5qnwh3ww7n4sptrzh6/bafkreih2a7ktohutgzans3h6zqq5gj2vfjhrd7zn6kev375kzciq57mz64@jpeg",
#             "fullsize": "https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:hod2pn5qnwh3ww7n4sptrzh6/bafkreih2a7ktohutgzans3h6zqq5gj2vfjhrd7zn6kev375kzciq57mz64@jpeg",
#             "alt": "",
#             "aspectRatio": {
#               "height": 2000,
#               "width": 1500
#             }
#           }
#         ]
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 2,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T17:13:29.507Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:3w3leed7wguzrfvt7djulgjz/app.bsky.feed.post/3lz2dgnijkc2i",
#       "cid": "bafyreiead3f3edyakz7mv4lz6wgscqpqd6in4gg3d5bdzlynq5lh3hamti",
#       "author": {
#         "did": "did:plc:3w3leed7wguzrfvt7djulgjz",
#         "handle": "gge66.bsky.social",
#         "displayName": "",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:3w3leed7wguzrfvt7djulgjz/bafkreied5zkmfyjuflkigkum4x6h5tfusig7jslh6vnk64v3plrb5k2ei4@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2025-02-22T12:10:41.045Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T17:12:59.541Z",
#         "facets": [
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "Eel"
#               }
#             ],
#             "index": {
#               "byteEnd": 230,
#               "byteStart": 226
#             }
#           },
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "ICES"
#               }
#             ],
#             "index": {
#               "byteEnd": 236,
#               "byteStart": 231
#             }
#           },
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "ISEAL"
#               }
#             ],
#             "index": {
#               "byteEnd": 243,
#               "byteStart": 237
#             }
#           },
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "EUlaw"
#               }
#             ],
#             "index": {
#               "byteEnd": 250,
#               "byteStart": 244
#             }
#           },
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "EelRegulation"
#               }
#             ],
#             "index": {
#               "byteEnd": 265,
#               "byteStart": 251
#             }
#           },
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "Fisheries"
#               }
#             ],
#             "index": {
#               "byteEnd": 276,
#               "byteStart": 266
#             }
#           }
#         ],
#         "langs": [
#           "en"
#         ],
#         "reply": {
#           "parent": {
#             "cid": "bafyreihvqlvxlot2ca7tug64iz5a257gmoulobkws4vo4gghppmvshiy2i",
#             "uri": "at://did:plc:3w3leed7wguzrfvt7djulgjz/app.bsky.feed.post/3lz2dflkbrs2i"
#           },
#           "root": {
#             "cid": "bafyreidegbdofrepmnet24ybg4pfds4hv6c4wyang37i5umu2l5xojhqcm",
#             "uri": "at://did:plc:3w3leed7wguzrfvt7djulgjz/app.bsky.feed.post/3lz2d7i72ps2i"
#           }
#         },
#         "text": "10/10\n\nEurope\u2019s eel populations are collapsing.\nICES science is clear.\nSEG\u2019s current certification practices ignore both data and law.\n\nUntil escapement targets are met and verified, SEG must stop certifying. Full stop. \n\n#Eel #ICES #ISEAL #EUlaw #EelRegulation #Fisheries"
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 0,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T17:13:00.507Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:n5j4ylwlhqbvl22i3kts3duj/app.bsky.feed.post/3lz2dceu7ic2d",
#       "cid": "bafyreift6ousvsr6wzxvzop6lfqovenubdz5ugfa72yyqroucowjylucy4",
#       "author": {
#         "did": "did:plc:n5j4ylwlhqbvl22i3kts3duj",
#         "handle": "chrismf.bsky.social",
#         "displayName": "",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:n5j4ylwlhqbvl22i3kts3duj/bafkreib6rxrbstmadl6qk4yq4q2s4gtnx7rj3kmalb35jkskrheanaixqu@jpeg",
#         "associated": {
#           "chat": {
#             "allowIncoming": "all"
#           },
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2024-11-13T05:01:41.485Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T17:10:36.269Z",
#         "langs": [
#           "en"
#         ],
#         "text": "Susan Monarez blew the whistle on RFK Jr.\u2019s horrific vaccine policy, making changes to kids vaccines WITHOUT a lick of science or data to back that move.\n\nHow did we end up with this pre- dawn of reason unqualified freak?\n\nOh that\u2019s right. The demented pedophile Trump!"
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 0,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T17:10:37.302Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:xqcyvnlq4pa7fm7sbligxr3d/app.bsky.feed.post/3lz2d67f4ok2j",
#       "cid": "bafyreih7mxit7qvrxu4fbapmwutxbrn6bhjoeehshupnzrr5vtjnvrnliy",
#       "author": {
#         "did": "did:plc:xqcyvnlq4pa7fm7sbligxr3d",
#         "handle": "cenewman0.bsky.social",
#         "displayName": "Cathy Newman \u269c\ufe0f\ud83d\udc18",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:xqcyvnlq4pa7fm7sbligxr3d/bafkreieffq2i3ygefvastzp3ljipo5iiglzsjaeiikgtxonhwentftw73a@jpeg",
#         "associated": {
#           "chat": {
#             "allowIncoming": "all"
#           },
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2023-07-26T12:49:59.784Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T17:08:16.305Z",
#         "embed": {
#           "$type": "app.bsky.embed.images",
#           "images": [
#             {
#               "alt": "",
#               "aspectRatio": {
#                 "height": 1500,
#                 "width": 2000
#               },
#               "image": {
#                 "$type": "blob",
#                 "ref": {
#                   "$link": "bafkreif3hst2lpt3w737lv4fozzejnsogahpobki4u2ub5l7nbz4tjtbae"
#                 },
#                 "mimeType": "image/jpeg",
#                 "size": 981557
#               }
#             },
#             {
#               "alt": "",
#               "aspectRatio": {
#                 "height": 1500,
#                 "width": 2000
#               },
#               "image": {
#                 "$type": "blob",
#                 "ref": {
#                   "$link": "bafkreigamjen6fbcvtyc6lixwrehi2tgtj54igntszpzurxfu5zrlnmwhy"
#                 },
#                 "mimeType": "image/jpeg",
#                 "size": 978001
#               }
#             },
#             {
#               "alt": "",
#               "aspectRatio": {
#                 "height": 1500,
#                 "width": 2000
#               },
#               "image": {
#                 "$type": "blob",
#                 "ref": {
#                   "$link": "bafkreibr2w5xdtuxpkaxuttfvlju2yskoxi26h42ewivq37f4rurlqpbxm"
#                 },
#                 "mimeType": "image/jpeg",
#                 "size": 883989
#               }
#             }
#           ]
#         },
#         "langs": [
#           "en"
#         ],
#         "text": "Bird safe glass windows on the new Genomic Medicine & Data Science building at UAB (cool double helix design as a whole but here's a close-up)"
#       },
#       "embed": {
#         "$type": "app.bsky.embed.images#view",
#         "images": [
#           {
#             "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:xqcyvnlq4pa7fm7sbligxr3d/bafkreif3hst2lpt3w737lv4fozzejnsogahpobki4u2ub5l7nbz4tjtbae@jpeg",
#             "fullsize": "https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:xqcyvnlq4pa7fm7sbligxr3d/bafkreif3hst2lpt3w737lv4fozzejnsogahpobki4u2ub5l7nbz4tjtbae@jpeg",
#             "alt": "",
#             "aspectRatio": {
#               "height": 1500,
#               "width": 2000
#             }
#           },
#           {
#             "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:xqcyvnlq4pa7fm7sbligxr3d/bafkreigamjen6fbcvtyc6lixwrehi2tgtj54igntszpzurxfu5zrlnmwhy@jpeg",
#             "fullsize": "https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:xqcyvnlq4pa7fm7sbligxr3d/bafkreigamjen6fbcvtyc6lixwrehi2tgtj54igntszpzurxfu5zrlnmwhy@jpeg",
#             "alt": "",
#             "aspectRatio": {
#               "height": 1500,
#               "width": 2000
#             }
#           },
#           {
#             "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:xqcyvnlq4pa7fm7sbligxr3d/bafkreibr2w5xdtuxpkaxuttfvlju2yskoxi26h42ewivq37f4rurlqpbxm@jpeg",
#             "fullsize": "https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:xqcyvnlq4pa7fm7sbligxr3d/bafkreibr2w5xdtuxpkaxuttfvlju2yskoxi26h42ewivq37f4rurlqpbxm@jpeg",
#             "alt": "",
#             "aspectRatio": {
#               "height": 1500,
#               "width": 2000
#             }
#           }
#         ]
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 2,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T17:08:19.613Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:ejefjpxwl7kjyktx44cx3hlb/app.bsky.feed.post/3lz2d4w6yyl23",
#       "cid": "bafyreig57glei36ncvucdxoa4gpahhi4wz7wb7smrcgxuspw6bs3evaapy",
#       "author": {
#         "did": "did:plc:ejefjpxwl7kjyktx44cx3hlb",
#         "handle": "cboettig.bsky.social",
#         "displayName": "Carl Boettiger ",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:ejefjpxwl7kjyktx44cx3hlb/bafkreig3wl34a424n77ap6evxqtv27rgdp7ehvi4g7obww5x32i4ilxrou@jpeg",
#         "associated": {
#           "chat": {
#             "allowIncoming": "following"
#           },
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2023-09-25T02:22:28.051Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T17:07:33.120Z",
#         "langs": [
#           "en"
#         ],
#         "reply": {
#           "parent": {
#             "cid": "bafyreihj2i7o2b4nnjx3fiqdp6dcymfilxgw3x6njsq5pfwxx6r2be64qm",
#             "uri": "at://did:plc:ejefjpxwl7kjyktx44cx3hlb/app.bsky.feed.post/3lz2d4w6yyk23"
#           },
#           "root": {
#             "cid": "bafyreibr2q2il4jrx5l7rjqqxyvaioqpqs2g2xtwir43gqzkkcagbkp6ka",
#             "uri": "at://did:plc:ejefjpxwl7kjyktx44cx3hlb/app.bsky.feed.post/3lz2d4w6t5223"
#           }
#         },
#         "text": "Meanwhile, much science and funder rhetoric seems squarely centered on the proposition that (academic) researchers will progress by somehow 'training new AI models' on ever more data."
#       },
#       "bookmarkCount": 0,
#       "replyCount": 1,
#       "repostCount": 0,
#       "likeCount": 0,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T17:07:33.765Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:f6uxkmrsq2xeqfs4pfjrpsi7/app.bsky.feed.post/3lz2d3ztikg2b",
#       "cid": "bafyreihiq5k3wbpvgj6qw6axv7worvhtvpqyv7e5txjarh77otbly22cr4",
#       "author": {
#         "did": "did:plc:f6uxkmrsq2xeqfs4pfjrpsi7",
#         "handle": "uvadatascience.bsky.social",
#         "displayName": "UVA School of Data Science",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:f6uxkmrsq2xeqfs4pfjrpsi7/bafkreicsxi4el56x2ho2casr6ht27rtjlivral5ow6fadoanft2bnljliu@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2024-11-19T16:09:50.906Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T17:07:03.244016853Z",
#         "embed": {
#           "$type": "app.bsky.embed.images",
#           "external": null,
#           "images": [
#             {
#               "alt": "Promotional poster for 2025 National Postdoc Appreciation Week by UVA School of Data Science. Features The School of Data Science building overlooking a pond, under a clear blue sky. Text thanks postdocs for their contributions to research and scholarship.",
#               "aspectRatio": {
#                 "height": 1350,
#                 "width": 1080
#               },
#               "image": {
#                 "$type": "blob",
#                 "ref": {
#                   "$link": "bafkreiauy5j4zjgt7jwdpdkud7ji3rmgzmdfnsmthyzow7zcmdwlt6spau"
#                 },
#                 "mimeType": "image/jpeg",
#                 "size": 217178
#               }
#             }
#           ],
#           "record": null,
#           "video": null
#         },
#         "text": "Happy National Postdoc Appreciation week. Join us in extending a big thank you to our postdocs for their incredible contributions to research and scholarship \ud83c\udf89 "
#       },
#       "embed": {
#         "$type": "app.bsky.embed.images#view",
#         "images": [
#           {
#             "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:f6uxkmrsq2xeqfs4pfjrpsi7/bafkreiauy5j4zjgt7jwdpdkud7ji3rmgzmdfnsmthyzow7zcmdwlt6spau@jpeg",
#             "fullsize": "https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:f6uxkmrsq2xeqfs4pfjrpsi7/bafkreiauy5j4zjgt7jwdpdkud7ji3rmgzmdfnsmthyzow7zcmdwlt6spau@jpeg",
#             "alt": "Promotional poster for 2025 National Postdoc Appreciation Week by UVA School of Data Science. Features The School of Data Science building overlooking a pond, under a clear blue sky. Text thanks postdocs for their contributions to research and scholarship.",
#             "aspectRatio": {
#               "height": 1350,
#               "width": 1080
#             }
#           }
#         ]
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 0,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T17:07:04.103Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:e2b2eua6schximsdhf5leauk/app.bsky.feed.post/3lz2cxtnnn222",
#       "cid": "bafyreiczfcao6ujvrtfna5ha5axbcujuoimxua4vkqzvytu5yy2rftufre",
#       "author": {
#         "did": "did:plc:e2b2eua6schximsdhf5leauk",
#         "handle": "changethechamber.bsky.social",
#         "displayName": "Change the Chamber",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:e2b2eua6schximsdhf5leauk/bafkreihlhfkblgzbt7dgkfbf3tmalklby3spvlc3nntdikin6udbdtnqxy@jpeg",
#         "associated": {
#           "chat": {
#             "allowIncoming": "all"
#           },
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2024-11-15T15:02:52.222Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T17:04:42.684Z",
#         "embed": {
#           "$type": "app.bsky.embed.external",
#           "external": {
#             "description": "Pamela McElwee joined a group of 85 climate scientists who refuted DOE\u2019s faulty science last week. Trump\u2019s climate denialism, she believes, is designed to sow confusion\u2014and inaction.",
#             "thumb": {
#               "$type": "blob",
#               "ref": {
#                 "$link": "bafkreidtbmswkjiijt67k7fkzoctzituvhqttxvhpkdbh5kbweo75iumzq"
#               },
#               "mimeType": "image/jpeg",
#               "size": 730136
#             },
#             "title": "An Energy Department Climate Change Report \u2018Completely Ignored\u2019 Adaptation, Rutgers Professor Says - Inside Climate News",
#             "uri": "https://insideclimatenews.org/news/10092025/pamela-mcelwee-energy-department-greenhouse-gas-report/"
#           }
#         },
#         "facets": [
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "climate"
#               }
#             ],
#             "index": {
#               "byteEnd": 16,
#               "byteStart": 8
#             }
#           }
#         ],
#         "langs": [
#           "en"
#         ],
#         "text": "DOE\u2019s #climate report wasn\u2019t science\u2014it was spin.\n\u274c Cherry-picked data\n\u274c Bad citations\n\u274c Ignored adaptation\n85 scientists fought back."
#       },
#       "embed": {
#         "$type": "app.bsky.embed.external#view",
#         "external": {
#           "uri": "https://insideclimatenews.org/news/10092025/pamela-mcelwee-energy-department-greenhouse-gas-report/",
#           "title": "An Energy Department Climate Change Report \u2018Completely Ignored\u2019 Adaptation, Rutgers Professor Says - Inside Climate News",
#           "description": "Pamela McElwee joined a group of 85 climate scientists who refuted DOE\u2019s faulty science last week. Trump\u2019s climate denialism, she believes, is designed to sow confusion\u2014and inaction.",
#           "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:e2b2eua6schximsdhf5leauk/bafkreidtbmswkjiijt67k7fkzoctzituvhqttxvhpkdbh5kbweo75iumzq@jpeg"
#         }
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 1,
#       "likeCount": 2,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T17:04:45.913Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:n5j4ylwlhqbvl22i3kts3duj/app.bsky.feed.post/3lz2cwmybwk2d",
#       "cid": "bafyreidgvwy5ajulvhbbow3mcugccmjmpug57k6xjwizyz5iarsrcfwujy",
#       "author": {
#         "did": "did:plc:n5j4ylwlhqbvl22i3kts3duj",
#         "handle": "chrismf.bsky.social",
#         "displayName": "",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:n5j4ylwlhqbvl22i3kts3duj/bafkreib6rxrbstmadl6qk4yq4q2s4gtnx7rj3kmalb35jkskrheanaixqu@jpeg",
#         "associated": {
#           "chat": {
#             "allowIncoming": "all"
#           },
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2024-11-13T05:01:41.485Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T17:04:02.138Z",
#         "langs": [
#           "en"
#         ],
#         "text": "Former Director of the CDC Dr. Susan Monarez blew the whistle on RFK Jr.\u2019s horrific vaccine policy, making changes to kids vaccines WITHOUT a lick of science or data to back that move.\nCmon get rid of the road kill eating charlatan!"
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 0,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T17:04:03.303Z",
#       "labels": []
#     }
#   ],
#   "cursor": "10"
# }

# %%
rows = []
for post in data["posts"]:
    rows.append({
        "Author": post["author"].get("displayName"),
        "Text": post["record"].get("text"),
        "Likes": post.get("likeCount", 0),
        "Timestamp": post["record"].get("createdAt")
    })

# %%
# Create DataFrame
df = pd.DataFrame(rows, columns=["Author", "Text", "Likes", "Timestamp"])

# Show as table in Jupyter
df.head()
# Out:
#                  Author                                               Text  \
# 0       Nabeel Siddiqui  My book Cultural Analytics in R: A Tidy Approa...
# 1  UBC Computer Science  The Distinguished Lecture Series is back! Lear...
# 2               Madison  Happy first day of #positconf2025 to those who...
# 3                        10/10\n\nEurope’s eel populations are collapsi...
# 4                        Susan Monarez blew the whistle on RFK Jr.’s ho...
#
#    Likes                 Timestamp
# 0      0  2025-09-17T17:33:20.603Z
# 1      0  2025-09-17T17:20:22.142Z
# 2      2  2025-09-17T17:13:25.065Z
# 3      0  2025-09-17T17:12:59.541Z
# 4      0  2025-09-17T17:10:36.269Z

# %% [markdown]
# # Authentication
# ## Openweathermaps
#
# To demonstrate authentication, you need to get an API key. <br>
# Go to https://home.openweathermap.org/api_keys

# %%
## New API keys can take up to 1–2 hours to become active.
API_KEY = "54557732afcfe106bfc955b9da04fb14"  # put your real key here
city = "Kent"
# f"" → lets you insert variables/expressions inside a string.
url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"

response = requests.get(url)

# %% [markdown]
# ## Display response

# %%
# Check if the request worked
if response.status_code == 200:
    data = response.json()
    print("City:", data["name"])
    print("Weather:", data["weather"][0]["description"])
    print("Temperature (C):", data["main"]["temp"])
else:
    print("Error:", response.status_code, response.text)
# Out:
# City: Kent
# Weather: overcast clouds
# Temperature (C): 18.19
