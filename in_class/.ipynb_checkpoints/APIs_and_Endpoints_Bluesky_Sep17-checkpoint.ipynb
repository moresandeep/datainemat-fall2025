# %% [markdown]
# # APIs and Endpoints — Bluesky Edition
#
# **Course theme:** Data Loop → *Question → Acquire → Analyze → Report*
# **Today’s focus:** Calling a real data API, understanding endpoints & parameters, and wrangling the JSON response.
#
# We’ll use the **Bluesky public API** for demonstrations. You’ll learn:
#
# - How to make HTTP requests with Python’s `requests`
# - How to read endpoint **parameters** and pass them correctly
# - How to parse the **JSON response** and load it into **pandas**
# - How to handle **pagination**, **rate limits**, and **errors**
# - How to save your results and think about **ethics** & **limitations** of API data

# %% [markdown]
# ## 0. Prerequisites
#
# ```bash
# # in your environment (Anaconda prompt or terminal)
# pip install requests
# ```

# %%
import time
from typing import Dict, Any, List, Optional
import requests
import pandas as pd
import json as js

BASE_URL = "https://api.bsky.app/xrpc"

# %% [markdown]
# ## 1) Quickstart: `requests` basics
#
# - **Make a GET request:** `requests.get(url, params={...}, headers={...})`
# - **Inspect status:** `resp.status_code` (200 = OK, 429 = rate-limited, 4xx/5xx = errors)
# - **Parse JSON:** `resp.json()`
# - **Headers & auth:** often required; some public endpoints don’t need auth
#
# We’ll start with a **public search endpoint** to avoid credentials.

# %% [markdown]
# ## 2) Endpoint: `app.bsky.feed.searchPosts` (public)
#
# This endpoint lets us search recent Bluesky posts.
#
# - **Method:** `GET`
# - **URL:** `https://api.bsky.app/xrpc/app.bsky.feed.searchPosts`
# - **Key parameters:**
#   - `q`: search query string (required)
#   - `limit`: number of results to return (suggest 10–50 for demos)
#   - `cursor`: for pagination (use the `cursor` returned from a prior call)
#
# > Note: Public APIs can change. If something fails today, check the official docs and reduce the scope of parameters.

# %%
endpoint = f"{BASE_URL}/app.bsky.feed.searchPosts"
headers = {"User-Agent": "EMAT-Teaching/1.0 (+contact@example.com)"}
params = {
    "q": "data science",
    "limit": 5,  # start small for demos
}

resp = requests.get(endpoint, params=params, headers=headers, timeout=30)
print("Status:", resp.status_code)
data = resp.json() if resp.headers.get("content-type", "").startswith("application/json") else {}
print("Top-level keys:", list(data.keys()))
print(js.dumps(data, indent=2))
# Out:
# Status: 200
# Top-level keys: ['posts', 'cursor']
# {
#   "posts": [
#     {
#       "uri": "at://did:plc:4iltr4zzr2xmi2ho4mcau7pt/app.bsky.feed.post/3lyzn5ujno22b",
#       "cid": "bafyreiehmbfx5zhzlu5r7afuza27ru6jy4kfjlv4wuatrqyb3knt234w3q",
#       "author": {
#         "did": "did:plc:4iltr4zzr2xmi2ho4mcau7pt",
#         "handle": "drrobgalloway.bsky.social",
#         "displayName": "Rob galloway",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:4iltr4zzr2xmi2ho4mcau7pt/bafkreiblsdhptcsmm73iab4qkvdpak5lumv6xaupgornmni6aadwfmkvby@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2024-10-18T12:32:51.605Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T10:34:22.596Z",
#         "embed": {
#           "$type": "app.bsky.embed.images",
#           "images": [
#             {
#               "alt": "",
#               "aspectRatio": {
#                 "height": 1478,
#                 "width": 1179
#               },
#               "image": {
#                 "$type": "blob",
#                 "ref": {
#                   "$link": "bafkreifm357kvsasnj4q7oxd6wjxpophbhdcyn6tlh4fwksjgdh3l5bili"
#                 },
#                 "mimeType": "image/jpeg",
#                 "size": 997943
#               }
#             }
#           ]
#         },
#         "langs": [
#           "en"
#         ],
#         "text": "Tobacco firms once dismissed smoking harms as \u201cjust data.\u201d Food giants now use the same playbook on sweeteners & ultra-processed food.\n\nThis week in the Mail I explore a landmark study. I trust science, not corporations \u2014 so no more diet drinks or sweetened yoghurts for my family."
#       },
#       "embed": {
#         "$type": "app.bsky.embed.images#view",
#         "images": [
#           {
#             "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:4iltr4zzr2xmi2ho4mcau7pt/bafkreifm357kvsasnj4q7oxd6wjxpophbhdcyn6tlh4fwksjgdh3l5bili@jpeg",
#             "fullsize": "https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:4iltr4zzr2xmi2ho4mcau7pt/bafkreifm357kvsasnj4q7oxd6wjxpophbhdcyn6tlh4fwksjgdh3l5bili@jpeg",
#             "alt": "",
#             "aspectRatio": {
#               "height": 1478,
#               "width": 1179
#             }
#           }
#         ]
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 0,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T10:34:26.008Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:2gsflwk77v2njmyhqw2bv3r3/app.bsky.feed.post/3lyzlvds4vt2d",
#       "cid": "bafyreifnt4bp77p7k3bn6ija5s6cd3cqyntweevlkw5nlzaw4m3clsodei",
#       "author": {
#         "did": "did:plc:2gsflwk77v2njmyhqw2bv3r3",
#         "handle": "betadevelopment.bsky.social",
#         "displayName": "Beta Development",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:2gsflwk77v2njmyhqw2bv3r3/bafkreidfbo2d6nup2xwlmtv5hpumx4yk3vejhzdwlu4n2asdq3tbvw4vfa@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2025-01-09T18:36:12.143Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T10:11:42.5669522+00:00",
#         "facets": [
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#link",
#                 "uri": "https://sciencebusiness.net/jobs/eureka-looking-trainee-strategy-business-development-and-data-0"
#               }
#             ],
#             "index": {
#               "byteEnd": 272,
#               "byteStart": 176
#             }
#           },
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "Science"
#               }
#             ],
#             "index": {
#               "byteEnd": 282,
#               "byteStart": 274
#             }
#           },
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "Business"
#               }
#             ],
#             "index": {
#               "byteEnd": 292,
#               "byteStart": 283
#             }
#           }
#         ],
#         "langs": [
#           "en-US"
#         ],
#         "text": "Science|Business\nEureka is looking for a Trainee in Strategy, Business Development and Data\n\nHave you recently graduated? In 2022, we launched the Eureka traineeship progr...\n\nhttps://sciencebusiness.net/jobs/eureka-looking-trainee-strategy-business-development-and-data-0\n\n#Science #Business"
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 0,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T10:11:43.302Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:qp7epa7pwfgjks53jgkxogpt/app.bsky.feed.post/3lyzleq3u6s2v",
#       "cid": "bafyreigo3ybs6pe5lqohpkis7lodz54qidnlfoay6xk4j7zjuxgtwjnuqm",
#       "author": {
#         "did": "did:plc:qp7epa7pwfgjks53jgkxogpt",
#         "handle": "ewancolman.bsky.social",
#         "displayName": "Ewan Colman",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:qp7epa7pwfgjks53jgkxogpt/bafkreieiczadz4gntdp5hqhkokglgt2fhdtpzwjee5meg3crznxft3wyaa@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2024-08-15T13:14:32.788Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T10:02:23.005Z",
#         "langs": [
#           "en"
#         ],
#         "reply": {
#           "parent": {
#             "cid": "bafyreidsf5smczone3cthuc3knkoatwyvzriyvnyx3kfd3cea7iwap2irq",
#             "uri": "at://did:plc:qp7epa7pwfgjks53jgkxogpt/app.bsky.feed.post/3lyzlephuk22v"
#           },
#           "root": {
#             "cid": "bafyreicp4qe5yw2c6ppueqpb6d32nbzbkdlodmccjad6wt3cxfbzgi6hoa",
#             "uri": "at://did:plc:qp7epa7pwfgjks53jgkxogpt/app.bsky.feed.post/3lyzlentxfs2v"
#           }
#         },
#         "text": "This would be perfect for someone good at quantitative stuff - maths, coding, data science, etc - but also interested in the lived experience of people at risk of disease and tough decisions they have to make each day. If that is you, email me right now!!! \ud83d\ude4f\ud83d\ude01"
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 1,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T10:02:26.445Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:xzfmi6z27c66fjajjeiyxvyr/app.bsky.feed.post/3lyzkcehnlu2o",
#       "cid": "bafyreiasbpq7f5f3nhdvkvigxxi5atcmvlbqlkflckblcnasugbhtupqdi",
#       "author": {
#         "did": "did:plc:xzfmi6z27c66fjajjeiyxvyr",
#         "handle": "cmn-vib.bsky.social",
#         "displayName": "",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:xzfmi6z27c66fjajjeiyxvyr/bafkreihdnk3p7fix6gkf7zif24dmo6tmsn7smkuyfb6plifmvx3vv3wuga@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2025-01-16T14:20:43.344Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T11:43:10+02:00",
#         "embed": {
#           "$type": "app.bsky.embed.images",
#           "images": [
#             {
#               "alt": "",
#               "aspectRatio": {
#                 "height": 1600,
#                 "width": 2400
#               },
#               "image": {
#                 "$type": "blob",
#                 "ref": {
#                   "$link": "bafkreig6vno2f2f3o3eprqmcp2xowynx6ofjoxpheo2qqktfqekqivrvei"
#                 },
#                 "mimeType": "image/jpeg",
#                 "size": 782455
#               }
#             }
#           ]
#         },
#         "facets": [
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#link",
#                 "uri": "https://blog.vib.be/from-first-families-to-first-trials"
#               }
#             ],
#             "index": {
#               "byteEnd": 277,
#               "byteStart": 222
#             }
#           }
#         ],
#         "text": "When the gene is mapped, the work is far from done.\n\nIn this interview with Julie van der Zee, we talk why long-horizon science only delivers if relationships, records, and ethics are cared for as diligently as the data.\n\nhttps://blog.vib.be/from-first-families-to-first-trials"
#       },
#       "embed": {
#         "$type": "app.bsky.embed.images#view",
#         "images": [
#           {
#             "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:xzfmi6z27c66fjajjeiyxvyr/bafkreig6vno2f2f3o3eprqmcp2xowynx6ofjoxpheo2qqktfqekqivrvei@jpeg",
#             "fullsize": "https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:xzfmi6z27c66fjajjeiyxvyr/bafkreig6vno2f2f3o3eprqmcp2xowynx6ofjoxpheo2qqktfqekqivrvei@jpeg",
#             "alt": "",
#             "aspectRatio": {
#               "height": 1600,
#               "width": 2400
#             }
#           }
#         ]
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 0,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T09:43:13.302Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:4gbz657lwu4anfh3gc5rudc2/app.bsky.feed.post/3lyzj6b3vua22",
#       "cid": "bafyreicfcz5j7gqoou4lixmmtucuwvrlpebsyp6gxnzqo2phklmypyzscq",
#       "author": {
#         "did": "did:plc:4gbz657lwu4anfh3gc5rudc2",
#         "handle": "warwickstats.bsky.social",
#         "displayName": "Warwick Statistics",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:4gbz657lwu4anfh3gc5rudc2/bafkreib62tvzipwtq6e23euyxspaluxsvh2r5vl6e2ocyuqonzeyn7ay5m@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2024-09-23T08:40:31.007Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T09:23:00.000Z",
#         "langs": [],
#         "reply": {
#           "parent": {
#             "cid": "bafyreigmwfcfi2gwi6muuiqblwe2cwgn2weookcyeejzzne6uigr3h5yo4",
#             "uri": "at://did:plc:4gbz657lwu4anfh3gc5rudc2/app.bsky.feed.post/3lyzj63iljk2m"
#           },
#           "root": {
#             "cid": "bafyreigmwfcfi2gwi6muuiqblwe2cwgn2weookcyeejzzne6uigr3h5yo4",
#             "uri": "at://did:plc:4gbz657lwu4anfh3gc5rudc2/app.bsky.feed.post/3lyzj63iljk2m"
#           }
#         },
#         "text": "The Data Science programme is an undergraduate degree course jointly delivered by the Computer Science, Mathematics and Statistics departments at Warwick. The MORSE programme is jointly delivered by the Mathematics, Business School, Statistics and Economics departments."
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 0,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T09:23:01.101Z",
#       "labels": []
#     }
#   ],
#   "cursor": "5"
# }

# %% [markdown]
# ### Interpreting the response
#
# Typical top-level fields you may see:
#
# - `posts`: a list of post objects (each with author and record info)
# - `cursor`: a string to request the **next page**
#
# Each post commonly includes:
# - `uri`, `cid`: identifiers
# - `author`: nested object (e.g., `displayName`, `handle`, `did`)
# - `record`: nested object with `text` and timestamps (`createdAt`)
# - `indexedAt`: when Bluesky indexed the post
#
# Let’s normalize the JSON into a tidy table.

# %%
def flatten_posts(posts: List[Dict[str, Any]]) -> pd.DataFrame:
    rows = []
    for p in posts:
        author = p.get("author", {}) or {}
        record = p.get("record", {}) or {}
        rows.append({
            "uri": p.get("uri"),
            "cid": p.get("cid"),
            "author_handle": author.get("handle"),
            "author_name": author.get("displayName"),
            "indexed_at": p.get("indexedAt"),
            "created_at": record.get("createdAt"),
            "text": record.get("text"),
        })
    return pd.DataFrame(rows)

posts = data.get("posts", []) or []
df = flatten_posts(posts)
df.head(10)
# Out:
#                                                  uri  \
# 0  at://did:plc:uk2zxthkb4rurgew33wkfhwo/app.bsky...
# 1  at://did:plc:janrdq6lwlexzcae5x52yyff/app.bsky...
# 2  at://did:plc:rqzqrpmgvpdidh5557pbmyrw/app.bsky...
# 3  at://did:plc:4xo5m5dle6pl57oobivraajb/app.bsky...
# 4  at://did:plc:kxu57hzs7hkqinozalbd3tma/app.bsky...
#
#                                                  cid  \
# 0  bafyreiarj3lxbryvgjgmldd7gzvouqb2l5qicwcwlxg4q...
# 1  bafyreiahsnamogzvpz3l76cvsvsngigeahadaq6sa6yq3...
# 2  bafyreiaikbhcaozrtjr4bpo3x4rgz7jeap3sqiqeir7lj...
# 3  bafyreib7hgkbrx7wyrrwj7b7cgr3xllp6var7vtluxpaw...
# 4  bafyreigqjvhjsnrvtvynuyfutbt5axketovdsmx5o4sw5...
#
#                      author_handle                             author_name  \
# 0  rhetoric.streetwi.se.ap.brid.gy                                rhetoric
# 1          feiticeir0s.bsky.social                              Feiticeir0
# 2            scholarai.bsky.social     ScholarAI Research Agent on Bluesky
# 3            soosocean.bsky.social  Southern Ocean Observing System (SOOS)
# 4               u24usa.bsky.social
#
#                  indexed_at                created_at  \
# 0  2025-09-15T00:08:34.010Z  2025-09-15T00:07:57.000Z
# 1  2025-09-14T23:45:08.509Z  2025-09-14T23:45:05.328Z
# 2  2025-09-14T23:37:46.702Z  2025-09-14T23:37:46.285Z
# 3  2025-09-14T23:00:45.912Z  2025-09-14T23:00:45.405Z
# 4  2025-09-14T21:58:04.805Z      2025-09-14T21:58:02Z
#
#                                                 text
# 0  Instead of chasing more data, focus on what re...
# 1    Source: Towards Data Science\n search.app/3SqX9
# 2  A recent fascinating development in behavioral...
# 3  #SOOS_DATAMonday: 2x🤔 Think twice before publi...
# 4  The precarious future of consumer genetic priv...

# %% [markdown]
# ## 3) Basic wrangling & description
#
# Let’s transform timestamps, compute a few simple features, and do light EDA.

# %%
if not df.empty:
    # Convert to datetime
    for col in ["indexed_at", "created_at"]:
        df[col] = pd.to_datetime(df[col], errors="coerce")

    # Simple feature: text length
    df["text_len"] = df["text"].fillna("").str.len()

    display(df.head(5))
    print("\nSummary:")
    display(df.describe(include="all"))
else:
    print("No rows returned. Try a different query or reduce 'limit'.")
# Out:
#                                                  uri  \
# 0  at://did:plc:uk2zxthkb4rurgew33wkfhwo/app.bsky...
# 1  at://did:plc:janrdq6lwlexzcae5x52yyff/app.bsky...
# 2  at://did:plc:rqzqrpmgvpdidh5557pbmyrw/app.bsky...
# 3  at://did:plc:4xo5m5dle6pl57oobivraajb/app.bsky...
# 4  at://did:plc:kxu57hzs7hkqinozalbd3tma/app.bsky...
#
#                                                  cid  \
# 0  bafyreiarj3lxbryvgjgmldd7gzvouqb2l5qicwcwlxg4q...
# 1  bafyreiahsnamogzvpz3l76cvsvsngigeahadaq6sa6yq3...
# 2  bafyreiaikbhcaozrtjr4bpo3x4rgz7jeap3sqiqeir7lj...
# 3  bafyreib7hgkbrx7wyrrwj7b7cgr3xllp6var7vtluxpaw...
# 4  bafyreigqjvhjsnrvtvynuyfutbt5axketovdsmx5o4sw5...
#
#                      author_handle                             author_name  \
# 0  rhetoric.streetwi.se.ap.brid.gy                                rhetoric
# 1          feiticeir0s.bsky.social                              Feiticeir0
# 2            scholarai.bsky.social     ScholarAI Research Agent on Bluesky
# 3            soosocean.bsky.social  Southern Ocean Observing System (SOOS)
# 4               u24usa.bsky.social
#
#                         indexed_at                       created_at  \
# 0 2025-09-15 00:08:34.010000+00:00        2025-09-15 00:07:57+00:00
# 1 2025-09-14 23:45:08.509000+00:00 2025-09-14 23:45:05.328000+00:00
# 2 2025-09-14 23:37:46.702000+00:00 2025-09-14 23:37:46.285000+00:00
# 3 2025-09-14 23:00:45.912000+00:00 2025-09-14 23:00:45.405000+00:00
# 4 2025-09-14 21:58:04.805000+00:00                              NaT
#
#                                                 text  text_len
# 0  Instead of chasing more data, focus on what re...       294
# 1    Source: Towards Data Science\n search.app/3SqX9        46
# 2  A recent fascinating development in behavioral...       300
# 3  #SOOS_DATAMonday: 2x🤔 Think twice before publi...       258
# 4  The precarious future of consumer genetic priv...       195
# Summary:
#                                                       uri  \
# count                                                   5
# unique                                                  5
# top     at://did:plc:uk2zxthkb4rurgew33wkfhwo/app.bsky...
# freq                                                    1
# mean                                                  NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
# std                                                   NaN
#
#                                                       cid  \
# count                                                   5
# unique                                                  5
# top     bafyreiarj3lxbryvgjgmldd7gzvouqb2l5qicwcwlxg4q...
# freq                                                    1
# mean                                                  NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
# std                                                   NaN
#
#                           author_handle author_name  \
# count                                 5           5
# unique                                5           5
# top     rhetoric.streetwi.se.ap.brid.gy    rhetoric
# freq                                  1           1
# mean                                NaN         NaN
# min                                 NaN         NaN
# 25%                                 NaN         NaN
# 50%                                 NaN         NaN
# 75%                                 NaN         NaN
# max                                 NaN         NaN
# std                                 NaN         NaN
#
#                                  indexed_at  \
# count                                     5
# unique                                  NaN
# top                                     NaN
# freq                                    NaN
# mean    2025-09-14 23:18:03.987599872+00:00
# min        2025-09-14 21:58:04.805000+00:00
# 25%        2025-09-14 23:00:45.912000+00:00
# 50%     2025-09-14 23:37:46.702000128+00:00
# 75%     2025-09-14 23:45:08.508999936+00:00
# max        2025-09-15 00:08:34.010000+00:00
# std                                     NaN
#
#                                  created_at  \
# count                                     4
# unique                                  NaN
# top                                     NaN
# freq                                    NaN
# mean    2025-09-14 23:37:53.504499968+00:00
# min        2025-09-14 23:00:45.405000+00:00
# 25%     2025-09-14 23:28:31.064999936+00:00
# 50%     2025-09-14 23:41:25.806500096+00:00
# 75%     2025-09-14 23:50:48.246000128+00:00
# max               2025-09-15 00:07:57+00:00
# std                                     NaN
#
#                                                      text    text_len
# count                                                   5    5.000000
# unique                                                  5         NaN
# top     Instead of chasing more data, focus on what re...         NaN
# freq                                                    1         NaN
# mean                                                  NaN  218.600000
# min                                                   NaN   46.000000
# 25%                                                   NaN  195.000000
# 50%                                                   NaN  258.000000
# 75%                                                   NaN  294.000000
# max                                                   NaN  300.000000
# std                                                   NaN  105.132298

# %% [markdown]
# ## 4) Pagination with `cursor`
#
# Many APIs return a `cursor` to fetch the **next page**. We’ll write a helper to
# collect multiple pages while being gentle with rate limits.

# %%
def search_posts(query: str, pages: int = 3, per_page: int = 10, pause: float = 1.0) -> pd.DataFrame:
    endpoint = f"{BASE_URL}/app.bsky.feed.searchPosts"
    cursor: Optional[str] = None
    all_rows: List[Dict[str, Any]] = []

    for i in range(pages):
        params = {"q": query, "limit": per_page}
        if cursor:
            params["cursor"] = cursor

        r = requests.get(endpoint, params=params, timeout=30)
        if r.status_code == 429:
            # Rate-limited: wait and retry once
            time.sleep(5)
            r = requests.get(endpoint, params=params, timeout=30)

        if r.status_code != 200:
            print(f"Request {i+1} failed with status {r.status_code}. Stopping.")
            break

        j = r.json()
        posts = j.get("posts", []) or []
        df_page = flatten_posts(posts)
        all_rows.append(df_page)
        cursor = j.get("cursor")
        print(f"Page {i+1}: {len(df_page)} rows; next cursor present? {'yes' if cursor else 'no'}")

        if not cursor:
            break

        time.sleep(pause)  # be polite to the API

    return pd.concat(all_rows, ignore_index=True) if all_rows else pd.DataFrame()

df_multi = search_posts("machine learning", pages=2, per_page=15, pause=1.0)
df_multi.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 35
#      31         time.sleep(pause)  # be polite to the API
#      33     return pd.concat(all_rows, ignore_index=True) if all_rows else pd.DataFrame()
# ---> 35 df_multi = search_posts("machine learning", pages=2, per_page=15, pause=1.0)
#      36 df_multi.head(10)
#
# Cell In[5], line 23, in search_posts(query, pages, per_page, pause)
#      21 j = r.json()
#      22 posts = j.get("posts", []) or []
# ---> 23 df_page = flatten_posts(posts)
#      24 all_rows.append(df_page)
#      25 cursor = j.get("cursor")
#
# NameError: name 'flatten_posts' is not defined

# %% [markdown]
# ## 5) Save your results
#
# You can keep both the raw JSON and a clean CSV for later analysis/reproducibility.

# %%
# Save the last raw response (if present) and DataFrame
import os, json

os.makedirs("outputs", exist_ok=True)

# Save a minimal raw example
raw_path = "outputs/bluesky_search_raw.json"
with open(raw_path, "w", encoding="utf-8") as f:
    json.dump(data, f, ensure_ascii=False, indent=2)

# Save the wrangled table
csv_path = "outputs/bluesky_search_results.csv"
if not df.empty:
    df.to_csv(csv_path, index=False)

raw_path, os.path.exists(csv_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 13
#      11 # Save the wrangled table
#      12 csv_path = "outputs/bluesky_search_results.csv"
# ---> 13 if not df.empty:
#      14     df.to_csv(csv_path, index=False)
#      16 raw_path, os.path.exists(csv_path)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 6) Another endpoint: profile lookup
#
# Try `app.bsky.actor.getProfile` to resolve data for a handle.
#
# - **Method:** `GET`
# - **URL:** `https://public.api.bsky.app/xrpc/app.bsky.actor.getProfile`
# - **Parameter:** `actor` (handle or DID)

# %%
profile_endpoint = f"{BASE_URL}/app.bsky.actor.getProfile"
params = {"actor": "bsky.app"}  # try a known handle, or change this
r = requests.get(profile_endpoint, params=params, timeout=30)
print("Status:", r.status_code)
profile = r.json() if r.ok else {}
print(js.dumps(data, indent=2))
# Out:
# Status: 400
# {
#   "posts": [
#     {
#       "uri": "at://did:plc:4iltr4zzr2xmi2ho4mcau7pt/app.bsky.feed.post/3lyzn5ujno22b",
#       "cid": "bafyreiehmbfx5zhzlu5r7afuza27ru6jy4kfjlv4wuatrqyb3knt234w3q",
#       "author": {
#         "did": "did:plc:4iltr4zzr2xmi2ho4mcau7pt",
#         "handle": "drrobgalloway.bsky.social",
#         "displayName": "Rob galloway",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:4iltr4zzr2xmi2ho4mcau7pt/bafkreiblsdhptcsmm73iab4qkvdpak5lumv6xaupgornmni6aadwfmkvby@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2024-10-18T12:32:51.605Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T10:34:22.596Z",
#         "embed": {
#           "$type": "app.bsky.embed.images",
#           "images": [
#             {
#               "alt": "",
#               "aspectRatio": {
#                 "height": 1478,
#                 "width": 1179
#               },
#               "image": {
#                 "$type": "blob",
#                 "ref": {
#                   "$link": "bafkreifm357kvsasnj4q7oxd6wjxpophbhdcyn6tlh4fwksjgdh3l5bili"
#                 },
#                 "mimeType": "image/jpeg",
#                 "size": 997943
#               }
#             }
#           ]
#         },
#         "langs": [
#           "en"
#         ],
#         "text": "Tobacco firms once dismissed smoking harms as \u201cjust data.\u201d Food giants now use the same playbook on sweeteners & ultra-processed food.\n\nThis week in the Mail I explore a landmark study. I trust science, not corporations \u2014 so no more diet drinks or sweetened yoghurts for my family."
#       },
#       "embed": {
#         "$type": "app.bsky.embed.images#view",
#         "images": [
#           {
#             "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:4iltr4zzr2xmi2ho4mcau7pt/bafkreifm357kvsasnj4q7oxd6wjxpophbhdcyn6tlh4fwksjgdh3l5bili@jpeg",
#             "fullsize": "https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:4iltr4zzr2xmi2ho4mcau7pt/bafkreifm357kvsasnj4q7oxd6wjxpophbhdcyn6tlh4fwksjgdh3l5bili@jpeg",
#             "alt": "",
#             "aspectRatio": {
#               "height": 1478,
#               "width": 1179
#             }
#           }
#         ]
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 0,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T10:34:26.008Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:2gsflwk77v2njmyhqw2bv3r3/app.bsky.feed.post/3lyzlvds4vt2d",
#       "cid": "bafyreifnt4bp77p7k3bn6ija5s6cd3cqyntweevlkw5nlzaw4m3clsodei",
#       "author": {
#         "did": "did:plc:2gsflwk77v2njmyhqw2bv3r3",
#         "handle": "betadevelopment.bsky.social",
#         "displayName": "Beta Development",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:2gsflwk77v2njmyhqw2bv3r3/bafkreidfbo2d6nup2xwlmtv5hpumx4yk3vejhzdwlu4n2asdq3tbvw4vfa@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2025-01-09T18:36:12.143Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T10:11:42.5669522+00:00",
#         "facets": [
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#link",
#                 "uri": "https://sciencebusiness.net/jobs/eureka-looking-trainee-strategy-business-development-and-data-0"
#               }
#             ],
#             "index": {
#               "byteEnd": 272,
#               "byteStart": 176
#             }
#           },
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "Science"
#               }
#             ],
#             "index": {
#               "byteEnd": 282,
#               "byteStart": 274
#             }
#           },
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "Business"
#               }
#             ],
#             "index": {
#               "byteEnd": 292,
#               "byteStart": 283
#             }
#           }
#         ],
#         "langs": [
#           "en-US"
#         ],
#         "text": "Science|Business\nEureka is looking for a Trainee in Strategy, Business Development and Data\n\nHave you recently graduated? In 2022, we launched the Eureka traineeship progr...\n\nhttps://sciencebusiness.net/jobs/eureka-looking-trainee-strategy-business-development-and-data-0\n\n#Science #Business"
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 0,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T10:11:43.302Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:qp7epa7pwfgjks53jgkxogpt/app.bsky.feed.post/3lyzleq3u6s2v",
#       "cid": "bafyreigo3ybs6pe5lqohpkis7lodz54qidnlfoay6xk4j7zjuxgtwjnuqm",
#       "author": {
#         "did": "did:plc:qp7epa7pwfgjks53jgkxogpt",
#         "handle": "ewancolman.bsky.social",
#         "displayName": "Ewan Colman",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:qp7epa7pwfgjks53jgkxogpt/bafkreieiczadz4gntdp5hqhkokglgt2fhdtpzwjee5meg3crznxft3wyaa@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2024-08-15T13:14:32.788Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T10:02:23.005Z",
#         "langs": [
#           "en"
#         ],
#         "reply": {
#           "parent": {
#             "cid": "bafyreidsf5smczone3cthuc3knkoatwyvzriyvnyx3kfd3cea7iwap2irq",
#             "uri": "at://did:plc:qp7epa7pwfgjks53jgkxogpt/app.bsky.feed.post/3lyzlephuk22v"
#           },
#           "root": {
#             "cid": "bafyreicp4qe5yw2c6ppueqpb6d32nbzbkdlodmccjad6wt3cxfbzgi6hoa",
#             "uri": "at://did:plc:qp7epa7pwfgjks53jgkxogpt/app.bsky.feed.post/3lyzlentxfs2v"
#           }
#         },
#         "text": "This would be perfect for someone good at quantitative stuff - maths, coding, data science, etc - but also interested in the lived experience of people at risk of disease and tough decisions they have to make each day. If that is you, email me right now!!! \ud83d\ude4f\ud83d\ude01"
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 1,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T10:02:26.445Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:xzfmi6z27c66fjajjeiyxvyr/app.bsky.feed.post/3lyzkcehnlu2o",
#       "cid": "bafyreiasbpq7f5f3nhdvkvigxxi5atcmvlbqlkflckblcnasugbhtupqdi",
#       "author": {
#         "did": "did:plc:xzfmi6z27c66fjajjeiyxvyr",
#         "handle": "cmn-vib.bsky.social",
#         "displayName": "",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:xzfmi6z27c66fjajjeiyxvyr/bafkreihdnk3p7fix6gkf7zif24dmo6tmsn7smkuyfb6plifmvx3vv3wuga@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2025-01-16T14:20:43.344Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T11:43:10+02:00",
#         "embed": {
#           "$type": "app.bsky.embed.images",
#           "images": [
#             {
#               "alt": "",
#               "aspectRatio": {
#                 "height": 1600,
#                 "width": 2400
#               },
#               "image": {
#                 "$type": "blob",
#                 "ref": {
#                   "$link": "bafkreig6vno2f2f3o3eprqmcp2xowynx6ofjoxpheo2qqktfqekqivrvei"
#                 },
#                 "mimeType": "image/jpeg",
#                 "size": 782455
#               }
#             }
#           ]
#         },
#         "facets": [
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#link",
#                 "uri": "https://blog.vib.be/from-first-families-to-first-trials"
#               }
#             ],
#             "index": {
#               "byteEnd": 277,
#               "byteStart": 222
#             }
#           }
#         ],
#         "text": "When the gene is mapped, the work is far from done.\n\nIn this interview with Julie van der Zee, we talk why long-horizon science only delivers if relationships, records, and ethics are cared for as diligently as the data.\n\nhttps://blog.vib.be/from-first-families-to-first-trials"
#       },
#       "embed": {
#         "$type": "app.bsky.embed.images#view",
#         "images": [
#           {
#             "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:xzfmi6z27c66fjajjeiyxvyr/bafkreig6vno2f2f3o3eprqmcp2xowynx6ofjoxpheo2qqktfqekqivrvei@jpeg",
#             "fullsize": "https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:xzfmi6z27c66fjajjeiyxvyr/bafkreig6vno2f2f3o3eprqmcp2xowynx6ofjoxpheo2qqktfqekqivrvei@jpeg",
#             "alt": "",
#             "aspectRatio": {
#               "height": 1600,
#               "width": 2400
#             }
#           }
#         ]
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 0,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T09:43:13.302Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:4gbz657lwu4anfh3gc5rudc2/app.bsky.feed.post/3lyzj6b3vua22",
#       "cid": "bafyreicfcz5j7gqoou4lixmmtucuwvrlpebsyp6gxnzqo2phklmypyzscq",
#       "author": {
#         "did": "did:plc:4gbz657lwu4anfh3gc5rudc2",
#         "handle": "warwickstats.bsky.social",
#         "displayName": "Warwick Statistics",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:4gbz657lwu4anfh3gc5rudc2/bafkreib62tvzipwtq6e23euyxspaluxsvh2r5vl6e2ocyuqonzeyn7ay5m@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2024-09-23T08:40:31.007Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T09:23:00.000Z",
#         "langs": [],
#         "reply": {
#           "parent": {
#             "cid": "bafyreigmwfcfi2gwi6muuiqblwe2cwgn2weookcyeejzzne6uigr3h5yo4",
#             "uri": "at://did:plc:4gbz657lwu4anfh3gc5rudc2/app.bsky.feed.post/3lyzj63iljk2m"
#           },
#           "root": {
#             "cid": "bafyreigmwfcfi2gwi6muuiqblwe2cwgn2weookcyeejzzne6uigr3h5yo4",
#             "uri": "at://did:plc:4gbz657lwu4anfh3gc5rudc2/app.bsky.feed.post/3lyzj63iljk2m"
#           }
#         },
#         "text": "The Data Science programme is an undergraduate degree course jointly delivered by the Computer Science, Mathematics and Statistics departments at Warwick. The MORSE programme is jointly delivered by the Mathematics, Business School, Statistics and Economics departments."
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 0,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T09:23:01.101Z",
#       "labels": []
#     }
#   ],
#   "cursor": "5"
# }

# %% [markdown]
# ## 7) Errors, limits, and ethics
#
# - **Rate limits (429):** pause and retry modestly; don’t hammer endpoints.
# - **HTTP errors:** 400/404 (bad params or not found), 401/403 (auth issues), 5xx (server issues).
# - **Schema drift:** APIs change—defensive coding and **.get()** access help.
# - **Ethics:** Posts can be personal; be thoughtful about storing, sharing, and analyzing user-generated content. Respect terms of service and privacy norms.

# %% [markdown]
# ## 8) About authentication (optional for today)
#
# Some Bluesky endpoints require authentication using **App Passwords** and session creation. For public demos we used public endpoints. For private or write operations, consult the official docs, create an App Password (not your login password), and store credentials **securely** (e.g., in environment variables or a `.env` file, never hard-code secrets in notebooks).

# %% [markdown]
# ---
#
# ### ✅ Wrap-up
#
# - You practiced the **data loop** with real HTTP calls.
# - You learned how to read **endpoint docs**, pass parameters, and parse **JSON**.
# - You wrangled results into **pandas**, handled **pagination**, and saved outputs.
#
# *Last updated:* 2025-09-14 11:46:31
