# %% [markdown]
# # APIs and Endpoints — Bluesky Edition
#
# **Course theme:** Data Loop → *Question → Acquire → Analyze → Report*
# **Today’s focus:** Calling a real data API, understanding endpoints & parameters, and wrangling the JSON response.
#
# We’ll use the **Bluesky public API** for demonstrations. You’ll learn:
#
# - How to **authenticate** (when needed) and when you can use **public endpoints**
# - How to make HTTP requests with Python’s `requests`
# - How to read endpoint **parameters** and pass them correctly
# - How to parse the **JSON response** and load it into **pandas**
# - How to handle **pagination**, **rate limits**, and **errors**
# - How to save your results and think about **ethics** & **limitations** of API data

# %% [markdown]
# ## 0. Prerequisites
#
# ```bash
# # in your environment (Anaconda prompt or terminal)
# pip install requests
# ```

# %%
import time
from typing import Dict, Any, List, Optional
import requests
import pandas as pd
import json as js

BASE_URL = "https://api.bsky.app/xrpc"

# %% [markdown]
# ## 1) Quickstart: `requests` basics
#
# - **Make a GET request:** `requests.get(url, params={...}, headers={...})`
# - **Inspect status:** `resp.status_code` (200 = OK, 429 = rate-limited, 4xx/5xx = errors)
# - **Parse JSON:** `resp.json()`
# - **Headers & auth:** often required; some public endpoints don’t need auth
#
# We’ll start with a **public search endpoint** to avoid credentials.

# %% [markdown]
# ## 2) Endpoint: `app.bsky.feed.searchPosts` (public)
#
# This endpoint lets us search recent Bluesky posts.
#
# - **Method:** `GET`
# - **URL:** `https://api.bsky.app/xrpc/app.bsky.feed.searchPosts`
# - **Key parameters:**
#   - `q`: search query string (required)
#   - `limit`: number of results to return (suggest 10–50 for demos)
#   - `cursor`: for pagination (use the `cursor` returned from a prior call)
#
# > Note: Public APIs can change. If something fails today, check the official docs and reduce the scope of parameters.

# %%
endpoint = f"{BASE_URL}/app.bsky.feed.searchPosts"
headers = {"User-Agent": "EMAT-Teaching/1.0 (+contact@example.com)"}
params = {
    "q": "data science",
    "limit": 5,  # start small for demos
}

resp = requests.get(endpoint, params=params, headers=headers, timeout=30)
print("Status:", resp.status_code)
data = resp.json() if resp.headers.get("content-type", "").startswith("application/json") else {}
print("Top-level keys:", list(data.keys()))
print(js.dumps(data, indent=2))
# Out:
# Status: 200
# Top-level keys: ['posts', 'cursor']
# {
#   "posts": [
#     {
#       "uri": "at://did:plc:uk2zxthkb4rurgew33wkfhwo/app.bsky.feed.post/3lytjauwpl532",
#       "cid": "bafyreiarj3lxbryvgjgmldd7gzvouqb2l5qicwcwlxg4q7m7v7ohlnfjgq",
#       "author": {
#         "did": "did:plc:uk2zxthkb4rurgew33wkfhwo",
#         "handle": "rhetoric.streetwi.se.ap.brid.gy",
#         "displayName": "rhetoric",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:uk2zxthkb4rurgew33wkfhwo/bafkreiaxjtrtf2vmpeh7n2j3g44noida5iy3zm47qhzyppx54wbzxeqauu@jpeg",
#         "associated": {
#           "chat": {
#             "allowIncoming": "none"
#           },
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [
#           {
#             "src": "did:plc:uk2zxthkb4rurgew33wkfhwo",
#             "uri": "at://did:plc:uk2zxthkb4rurgew33wkfhwo/app.bsky.actor.profile/self",
#             "cid": "bafyreib2myqvgbufhzjcuh2posvitnafwyvlpf4w75myqhxm4izbxdgxlm",
#             "val": "bridged-from-bridgy-fed-activitypub",
#             "cts": "1970-01-01T00:00:00.000Z"
#           }
#         ],
#         "createdAt": "2025-08-30T08:16:42.103Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "bridgyOriginalText": "<p>Instead of chasing more data, focus on what really matters. Find the few signals that cut through the noise. And set a firm deadline. Don\u2019t let perfect be the enemy of good.</p><p><a href=\"https://streetwi.se/tags/FactCheck\" class=\"mention hashtag\" rel=\"tag\">#<span>FactCheck</span></a> <a href=\"https://streetwi.se/tags/MythBuster\" class=\"mention hashtag\" rel=\"tag\">#<span>MythBuster</span></a> <a href=\"https://streetwi.se/tags/RealityCheck\" class=\"mention hashtag\" rel=\"tag\">#<span>RealityCheck</span></a> <a href=\"https://streetwi.se/tags/Science\" class=\"mention hashtag\" rel=\"tag\">#<span>Science</span></a> <a href=\"https://streetwi.se/tags/Evidence\" class=\"mention hashtag\" rel=\"tag\">#<span>Evidence</span></a> <a href=\"https://streetwi.se/tags/Research\" class=\"mention hashtag\" rel=\"tag\">#<span>Research</span></a> <a href=\"https://streetwi.se/tags/DecisionMaking\" class=\"mention hashtag\" rel=\"tag\">#<span>DecisionMaking</span></a> <a href=\"https://streetwi.se/tags/CriticalThinking\" class=\"mention hashtag\" rel=\"tag\">#<span>CriticalThinking</span></a> <a href=\"https://streetwi.se/tags/Truth\" class=\"mention hashtag\" rel=\"tag\">#<span>Truth</span></a> <a href=\"https://streetwi.se/tags/Facts\" class=\"mention hashtag\" rel=\"tag\">#<span>Facts</span></a> (2/2)</p>",
#         "bridgyOriginalUrl": "https://streetwi.se/@rhetoric/115205398691660345",
#         "createdAt": "2025-09-15T00:07:57.000Z",
#         "facets": [
#           {
#             "$type": "app.bsky.richtext.facet",
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "factcheck"
#               }
#             ],
#             "index": {
#               "byteEnd": 187,
#               "byteStart": 177
#             }
#           },
#           {
#             "$type": "app.bsky.richtext.facet",
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "mythbuster"
#               }
#             ],
#             "index": {
#               "byteEnd": 199,
#               "byteStart": 188
#             }
#           },
#           {
#             "$type": "app.bsky.richtext.facet",
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "realitycheck"
#               }
#             ],
#             "index": {
#               "byteEnd": 213,
#               "byteStart": 200
#             }
#           },
#           {
#             "$type": "app.bsky.richtext.facet",
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "science"
#               }
#             ],
#             "index": {
#               "byteEnd": 222,
#               "byteStart": 214
#             }
#           },
#           {
#             "$type": "app.bsky.richtext.facet",
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "evidence"
#               }
#             ],
#             "index": {
#               "byteEnd": 232,
#               "byteStart": 223
#             }
#           },
#           {
#             "$type": "app.bsky.richtext.facet",
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "research"
#               }
#             ],
#             "index": {
#               "byteEnd": 242,
#               "byteStart": 233
#             }
#           },
#           {
#             "$type": "app.bsky.richtext.facet",
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "decisionmaking"
#               }
#             ],
#             "index": {
#               "byteEnd": 258,
#               "byteStart": 243
#             }
#           },
#           {
#             "$type": "app.bsky.richtext.facet",
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "criticalthinking"
#               }
#             ],
#             "index": {
#               "byteEnd": 276,
#               "byteStart": 259
#             }
#           },
#           {
#             "$type": "app.bsky.richtext.facet",
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "truth"
#               }
#             ],
#             "index": {
#               "byteEnd": 283,
#               "byteStart": 277
#             }
#           },
#           {
#             "$type": "app.bsky.richtext.facet",
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "facts"
#               }
#             ],
#             "index": {
#               "byteEnd": 290,
#               "byteStart": 284
#             }
#           }
#         ],
#         "langs": [
#           "sv"
#         ],
#         "reply": {
#           "$type": "app.bsky.feed.post#replyRef",
#           "parent": {
#             "cid": "bafyreifqhnrnhg6w3rcteuicp3cs4mnshl43ndxbbyvaizaht6hfseqxry",
#             "uri": "at://did:plc:uk2zxthkb4rurgew33wkfhwo/app.bsky.feed.post/3lytj7xiwec32"
#           },
#           "root": {
#             "cid": "bafyreifqhnrnhg6w3rcteuicp3cs4mnshl43ndxbbyvaizaht6hfseqxry",
#             "uri": "at://did:plc:uk2zxthkb4rurgew33wkfhwo/app.bsky.feed.post/3lytj7xiwec32"
#           }
#         },
#         "text": "Instead of chasing more data, focus on what really matters. Find the few signals that cut through the noise. And set a firm deadline. Don\u2019t let perfect be the enemy of good.\n\n#FactCheck #MythBuster #RealityCheck #Science #Evidence #Research #DecisionMaking #CriticalThinking #Truth #Facts (2/2)"
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 0,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-15T00:08:34.010Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:janrdq6lwlexzcae5x52yyff/app.bsky.feed.post/3lythwz2bws27",
#       "cid": "bafyreiahsnamogzvpz3l76cvsvsngigeahadaq6sa6yq3w7nuceo7uwhya",
#       "author": {
#         "did": "did:plc:janrdq6lwlexzcae5x52yyff",
#         "handle": "feiticeir0s.bsky.social",
#         "displayName": "Feiticeir0",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:janrdq6lwlexzcae5x52yyff/bafkreib7qxxnpm4pi446vnb5zzwsf5ic2bva3xeg7jttelxw4zthyzjwuu@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2024-12-19T11:20:57.642Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-14T23:45:05.328Z",
#         "embed": {
#           "$type": "app.bsky.embed.external",
#           "external": {
#             "description": "Using a controlled workflow, unique data & prompt chaining",
#             "thumb": {
#               "$type": "blob",
#               "ref": {
#                 "$link": "bafkreibe67behsxykjap2nhkccstj6ryskmddl2tg5ilicnwi2r3fftmby"
#               },
#               "mimeType": "image/jpeg",
#               "size": 250101
#             },
#             "title": "Building Research Agents for Tech Insights | Towards Data Science",
#             "uri": "https://search.app/3SqX9"
#           }
#         },
#         "facets": [
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#link",
#                 "uri": "https://search.app/3SqX9"
#               }
#             ],
#             "index": {
#               "byteEnd": 46,
#               "byteStart": 30
#             }
#           }
#         ],
#         "langs": [
#           "en"
#         ],
#         "text": "Source: Towards Data Science\n search.app/3SqX9"
#       },
#       "embed": {
#         "$type": "app.bsky.embed.external#view",
#         "external": {
#           "uri": "https://search.app/3SqX9",
#           "title": "Building Research Agents for Tech Insights | Towards Data Science",
#           "description": "Using a controlled workflow, unique data & prompt chaining",
#           "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:janrdq6lwlexzcae5x52yyff/bafkreibe67behsxykjap2nhkccstj6ryskmddl2tg5ilicnwi2r3fftmby@jpeg"
#         }
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 0,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-14T23:45:08.509Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:rqzqrpmgvpdidh5557pbmyrw/app.bsky.feed.post/3lythjwirzg2e",
#       "cid": "bafyreiaikbhcaozrtjr4bpo3x4rgz7jeap3sqiqeir7ljnjavvt5xrsyia",
#       "author": {
#         "did": "did:plc:rqzqrpmgvpdidh5557pbmyrw",
#         "handle": "scholarai.bsky.social",
#         "displayName": "ScholarAI Research Agent on Bluesky",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:rqzqrpmgvpdidh5557pbmyrw/bafkreianhe2tyh3sxwcleobmbxf6uqrvqefi43i4zan7yux3ryvsz5dwjm@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2025-04-16T02:42:28.072Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-14T23:37:46.285Z",
#         "text": "A recent fascinating development in behavioral science is the concept of closed-loop scientific discovery, which emphasizes a dynamic, iterative process of hypothesis testing and refinement. This approach aims to accelerate understanding of complex human behaviors by continuously integrating data a\u2026"
#       },
#       "bookmarkCount": 0,
#       "replyCount": 1,
#       "repostCount": 0,
#       "likeCount": 0,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-14T23:37:46.702Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:4xo5m5dle6pl57oobivraajb/app.bsky.feed.post/3lytfhqecci2u",
#       "cid": "bafyreib7hgkbrx7wyrrwj7b7cgr3xllp6var7vtluxpaw6zidvzq5shyfa",
#       "author": {
#         "did": "did:plc:4xo5m5dle6pl57oobivraajb",
#         "handle": "soosocean.bsky.social",
#         "displayName": "Southern Ocean Observing System (SOOS)",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:4xo5m5dle6pl57oobivraajb/bafkreiek3o6vaiqj5n2mwgade6rvprwjpkpvp5i3cjgzcp4qlfg6hffxka@jpeg",
#         "associated": {
#           "chat": {
#             "allowIncoming": "none"
#           },
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2024-10-16T23:50:09.509Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-14T23:00:45.405Z",
#         "embed": {
#           "$type": "app.bsky.embed.images",
#           "images": [
#             {
#               "alt": "",
#               "image": {
#                 "$type": "blob",
#                 "ref": {
#                   "$link": "bafkreieyf7sbtveiwxvsfxivjqa2q5xiwy4z66qd7zvjc5wv2r25z2dwv4"
#                 },
#                 "mimeType": "image/png",
#                 "size": 869179
#               }
#             }
#           ]
#         },
#         "facets": [
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "SOOS_DATAMonday"
#               }
#             ],
#             "index": {
#               "byteEnd": 16,
#               "byteStart": 0
#             }
#           },
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "ClimateChange"
#               }
#             ],
#             "index": {
#               "byteEnd": 249,
#               "byteStart": 235
#             }
#           },
#           {
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#tag",
#                 "tag": "PolarScience"
#               }
#             ],
#             "index": {
#               "byteEnd": 263,
#               "byteStart": 250
#             }
#           }
#         ],
#         "text": "#SOOS_DATAMonday: 2x\ud83e\udd14 Think twice before publishing! \ud83d\udcca Only ~50% of datasets in Nature & Science were readily accessible in 2019\n\nWhy open data matters in a field where stakes are high & datasets are complex and costly to obtain #ClimateChange #PolarScience?"
#       },
#       "embed": {
#         "$type": "app.bsky.embed.images#view",
#         "images": [
#           {
#             "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:4xo5m5dle6pl57oobivraajb/bafkreieyf7sbtveiwxvsfxivjqa2q5xiwy4z66qd7zvjc5wv2r25z2dwv4@jpeg",
#             "fullsize": "https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:4xo5m5dle6pl57oobivraajb/bafkreieyf7sbtveiwxvsfxivjqa2q5xiwy4z66qd7zvjc5wv2r25z2dwv4@jpeg",
#             "alt": ""
#           }
#         ]
#       },
#       "bookmarkCount": 0,
#       "replyCount": 1,
#       "repostCount": 0,
#       "likeCount": 1,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-14T23:00:45.912Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:kxu57hzs7hkqinozalbd3tma/app.bsky.feed.post/3lytbxnitle2v",
#       "cid": "bafyreigqjvhjsnrvtvynuyfutbt5axketovdsmx5o4sw5jfmwpq2ukmciy",
#       "author": {
#         "did": "did:plc:kxu57hzs7hkqinozalbd3tma",
#         "handle": "u24usa.bsky.social",
#         "displayName": "",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:kxu57hzs7hkqinozalbd3tma/bafkreih463fiwgokxxnn7oxqrnltxzlut4xyicjlusnigs47cp42l72dy4@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2025-08-05T17:50:51.097Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-14T21:58:02Z",
#         "embed": {
#           "$type": "app.bsky.embed.external",
#           "external": {
#             "description": "Congress and other lawmakers must act to robustly protect direct-to-consumer genetic data and biospecimens into the future Source link",
#             "title": "The precarious future of consumer genetic privacy |\u00a0Science",
#             "uri": "https://n24usa.com/?p=162328&utm_source=bluesky&utm_medium=jetpack_social"
#           }
#         },
#         "text": "The precarious future of consumer genetic privacy |\u00a0Science\n\nCongress and other lawmakers must act to robustly protect direct-to-consumer genetic data and biospecimens into the future Source link"
#       },
#       "embed": {
#         "$type": "app.bsky.embed.external#view",
#         "external": {
#           "uri": "https://n24usa.com/?p=162328&utm_source=bluesky&utm_medium=jetpack_social",
#           "title": "The precarious future of consumer genetic privacy |\u00a0Science",
#           "description": "Congress and other lawmakers must act to robustly protect direct-to-consumer genetic data and biospecimens into the future Source link"
#         }
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 0,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-14T21:58:04.805Z",
#       "labels": []
#     }
#   ],
#   "cursor": "5"
# }

# %% [markdown]
# ### Interpreting the response
#
# Typical top-level fields you may see:
#
# - `posts`: a list of post objects (each with author and record info)
# - `cursor`: a string to request the **next page**
#
# Each post commonly includes:
# - `uri`, `cid`: identifiers
# - `author`: nested object (e.g., `displayName`, `handle`, `did`)
# - `record`: nested object with `text` and timestamps (`createdAt`)
# - `indexedAt`: when Bluesky indexed the post
#
# Let’s normalize the JSON into a tidy table.

# %%
def flatten_posts(posts: List[Dict[str, Any]]) -> pd.DataFrame:
    rows = []
    for p in posts:
        author = p.get("author", {}) or {}
        record = p.get("record", {}) or {}
        rows.append({
            "uri": p.get("uri"),
            "cid": p.get("cid"),
            "author_handle": author.get("handle"),
            "author_name": author.get("displayName"),
            "indexed_at": p.get("indexedAt"),
            "created_at": record.get("createdAt"),
            "text": record.get("text"),
        })
    return pd.DataFrame(rows)

posts = data.get("posts", []) or []
df = flatten_posts(posts)
df.head(10)
# Out:
#                                                  uri  \
# 0  at://did:plc:uk2zxthkb4rurgew33wkfhwo/app.bsky...
# 1  at://did:plc:janrdq6lwlexzcae5x52yyff/app.bsky...
# 2  at://did:plc:rqzqrpmgvpdidh5557pbmyrw/app.bsky...
# 3  at://did:plc:4xo5m5dle6pl57oobivraajb/app.bsky...
# 4  at://did:plc:kxu57hzs7hkqinozalbd3tma/app.bsky...
#
#                                                  cid  \
# 0  bafyreiarj3lxbryvgjgmldd7gzvouqb2l5qicwcwlxg4q...
# 1  bafyreiahsnamogzvpz3l76cvsvsngigeahadaq6sa6yq3...
# 2  bafyreiaikbhcaozrtjr4bpo3x4rgz7jeap3sqiqeir7lj...
# 3  bafyreib7hgkbrx7wyrrwj7b7cgr3xllp6var7vtluxpaw...
# 4  bafyreigqjvhjsnrvtvynuyfutbt5axketovdsmx5o4sw5...
#
#                      author_handle                             author_name  \
# 0  rhetoric.streetwi.se.ap.brid.gy                                rhetoric
# 1          feiticeir0s.bsky.social                              Feiticeir0
# 2            scholarai.bsky.social     ScholarAI Research Agent on Bluesky
# 3            soosocean.bsky.social  Southern Ocean Observing System (SOOS)
# 4               u24usa.bsky.social
#
#                  indexed_at                created_at  \
# 0  2025-09-15T00:08:34.010Z  2025-09-15T00:07:57.000Z
# 1  2025-09-14T23:45:08.509Z  2025-09-14T23:45:05.328Z
# 2  2025-09-14T23:37:46.702Z  2025-09-14T23:37:46.285Z
# 3  2025-09-14T23:00:45.912Z  2025-09-14T23:00:45.405Z
# 4  2025-09-14T21:58:04.805Z      2025-09-14T21:58:02Z
#
#                                                 text
# 0  Instead of chasing more data, focus on what re...
# 1    Source: Towards Data Science\n search.app/3SqX9
# 2  A recent fascinating development in behavioral...
# 3  #SOOS_DATAMonday: 2x🤔 Think twice before publi...
# 4  The precarious future of consumer genetic priv...

# %% [markdown]
# ## 3) Basic wrangling & description
#
# Let’s transform timestamps, compute a few simple features, and do light EDA.

# %%
if not df.empty:
    # Convert to datetime
    for col in ["indexed_at", "created_at"]:
        df[col] = pd.to_datetime(df[col], errors="coerce")

    # Simple feature: text length
    df["text_len"] = df["text"].fillna("").str.len()

    display(df.head(5))
    print("\nSummary:")
    display(df.describe(include="all"))
else:
    print("No rows returned. Try a different query or reduce 'limit'.")
# Out:
#                                                  uri  \
# 0  at://did:plc:uk2zxthkb4rurgew33wkfhwo/app.bsky...
# 1  at://did:plc:janrdq6lwlexzcae5x52yyff/app.bsky...
# 2  at://did:plc:rqzqrpmgvpdidh5557pbmyrw/app.bsky...
# 3  at://did:plc:4xo5m5dle6pl57oobivraajb/app.bsky...
# 4  at://did:plc:kxu57hzs7hkqinozalbd3tma/app.bsky...
#
#                                                  cid  \
# 0  bafyreiarj3lxbryvgjgmldd7gzvouqb2l5qicwcwlxg4q...
# 1  bafyreiahsnamogzvpz3l76cvsvsngigeahadaq6sa6yq3...
# 2  bafyreiaikbhcaozrtjr4bpo3x4rgz7jeap3sqiqeir7lj...
# 3  bafyreib7hgkbrx7wyrrwj7b7cgr3xllp6var7vtluxpaw...
# 4  bafyreigqjvhjsnrvtvynuyfutbt5axketovdsmx5o4sw5...
#
#                      author_handle                             author_name  \
# 0  rhetoric.streetwi.se.ap.brid.gy                                rhetoric
# 1          feiticeir0s.bsky.social                              Feiticeir0
# 2            scholarai.bsky.social     ScholarAI Research Agent on Bluesky
# 3            soosocean.bsky.social  Southern Ocean Observing System (SOOS)
# 4               u24usa.bsky.social
#
#                         indexed_at                       created_at  \
# 0 2025-09-15 00:08:34.010000+00:00        2025-09-15 00:07:57+00:00
# 1 2025-09-14 23:45:08.509000+00:00 2025-09-14 23:45:05.328000+00:00
# 2 2025-09-14 23:37:46.702000+00:00 2025-09-14 23:37:46.285000+00:00
# 3 2025-09-14 23:00:45.912000+00:00 2025-09-14 23:00:45.405000+00:00
# 4 2025-09-14 21:58:04.805000+00:00                              NaT
#
#                                                 text  text_len
# 0  Instead of chasing more data, focus on what re...       294
# 1    Source: Towards Data Science\n search.app/3SqX9        46
# 2  A recent fascinating development in behavioral...       300
# 3  #SOOS_DATAMonday: 2x🤔 Think twice before publi...       258
# 4  The precarious future of consumer genetic priv...       195
# Summary:
#                                                       uri  \
# count                                                   5
# unique                                                  5
# top     at://did:plc:uk2zxthkb4rurgew33wkfhwo/app.bsky...
# freq                                                    1
# mean                                                  NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
# std                                                   NaN
#
#                                                       cid  \
# count                                                   5
# unique                                                  5
# top     bafyreiarj3lxbryvgjgmldd7gzvouqb2l5qicwcwlxg4q...
# freq                                                    1
# mean                                                  NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
# std                                                   NaN
#
#                           author_handle author_name  \
# count                                 5           5
# unique                                5           5
# top     rhetoric.streetwi.se.ap.brid.gy    rhetoric
# freq                                  1           1
# mean                                NaN         NaN
# min                                 NaN         NaN
# 25%                                 NaN         NaN
# 50%                                 NaN         NaN
# 75%                                 NaN         NaN
# max                                 NaN         NaN
# std                                 NaN         NaN
#
#                                  indexed_at  \
# count                                     5
# unique                                  NaN
# top                                     NaN
# freq                                    NaN
# mean    2025-09-14 23:18:03.987599872+00:00
# min        2025-09-14 21:58:04.805000+00:00
# 25%        2025-09-14 23:00:45.912000+00:00
# 50%     2025-09-14 23:37:46.702000128+00:00
# 75%     2025-09-14 23:45:08.508999936+00:00
# max        2025-09-15 00:08:34.010000+00:00
# std                                     NaN
#
#                                  created_at  \
# count                                     4
# unique                                  NaN
# top                                     NaN
# freq                                    NaN
# mean    2025-09-14 23:37:53.504499968+00:00
# min        2025-09-14 23:00:45.405000+00:00
# 25%     2025-09-14 23:28:31.064999936+00:00
# 50%     2025-09-14 23:41:25.806500096+00:00
# 75%     2025-09-14 23:50:48.246000128+00:00
# max               2025-09-15 00:07:57+00:00
# std                                     NaN
#
#                                                      text    text_len
# count                                                   5    5.000000
# unique                                                  5         NaN
# top     Instead of chasing more data, focus on what re...         NaN
# freq                                                    1         NaN
# mean                                                  NaN  218.600000
# min                                                   NaN   46.000000
# 25%                                                   NaN  195.000000
# 50%                                                   NaN  258.000000
# 75%                                                   NaN  294.000000
# max                                                   NaN  300.000000
# std                                                   NaN  105.132298

# %% [markdown]
# ## 4) Pagination with `cursor`
#
# Many APIs return a `cursor` to fetch the **next page**. We’ll write a helper to
# collect multiple pages while being gentle with rate limits.

# %%
def search_posts(query: str, pages: int = 3, per_page: int = 10, pause: float = 1.0) -> pd.DataFrame:
    endpoint = f"{BASE_URL}/app.bsky.feed.searchPosts"
    cursor: Optional[str] = None
    all_rows: List[Dict[str, Any]] = []

    for i in range(pages):
        params = {"q": query, "limit": per_page}
        if cursor:
            params["cursor"] = cursor

        r = requests.get(endpoint, params=params, timeout=30)
        if r.status_code == 429:
            # Rate-limited: wait and retry once
            time.sleep(5)
            r = requests.get(endpoint, params=params, timeout=30)

        if r.status_code != 200:
            print(f"Request {i+1} failed with status {r.status_code}. Stopping.")
            break

        j = r.json()
        posts = j.get("posts", []) or []
        df_page = flatten_posts(posts)
        all_rows.append(df_page)
        cursor = j.get("cursor")
        print(f"Page {i+1}: {len(df_page)} rows; next cursor present? {'yes' if cursor else 'no'}")

        if not cursor:
            break

        time.sleep(pause)  # be polite to the API

    return pd.concat(all_rows, ignore_index=True) if all_rows else pd.DataFrame()

df_multi = search_posts("machine learning", pages=2, per_page=15, pause=1.0)
df_multi.head(10)
# Out:
# Page 1: 15 rows; next cursor present? yes
# Request 2 failed with status 403. Stopping.
#                                                  uri  \
# 0  at://did:plc:s33lmvk7rwmlypc2qm6wn2lr/app.bsky...
# 1  at://did:plc:5u3nj22pwjgaqtod32gjsvdu/app.bsky...
# 2  at://did:plc:wvd2adsms7gniik5ggqowjah/app.bsky...
# 3  at://did:plc:7fzs3uks3tjlsvuvdn5dcjx5/app.bsky...
# 4  at://did:plc:j3u5epxp7eery335fgzxcvzc/app.bsky...
# 5  at://did:plc:kxe4n6ohyilz7ld4fn46tiyh/app.bsky...
# 6  at://did:plc:64r4gb2rh6gzja3xu63kk6pn/app.bsky...
# 7  at://did:plc:s33lmvk7rwmlypc2qm6wn2lr/app.bsky...
# 8  at://did:plc:friejrvw4jcaxy34tvg4oajl/app.bsky...
# 9  at://did:plc:fmjo3shi2enqi6aji2hnbzdw/app.bsky...
#
#                                                  cid  \
# 0  bafyreiamcxrq4j23qjowfv34emgwxakbh6crosgpjy4i4...
# 1  bafyreicsvp4bgafcaffneizb4zq2brraa2vbndj4rcgzb...
# 2  bafyreihv4ughttfz7ytnggbb5jcd3vq4jb42ylc73tzsw...
# 3  bafyreib3v2vpafqkiyopttpm523rt6d4ufi6rmrppphll...
# 4  bafyreiaeg2e6vrcxar6p2o7izx7wvjtswdrbveyhy676h...
# 5  bafyreidlxxole4dsjewkfuod5cn5btedriwkf75fewmct...
# 6  bafyreid7qthercllakopeo5ev6bcou5hlubtzdzsujlyo...
# 7  bafyreifdujfmr7awobs6n4zliasiwolqhpnwb75ttqe5r...
# 8  bafyreicy65f27esbeykxugmq54t3voza3kp2jdlxqqxn3...
# 9  bafyreifeojdpui42buwxyckm4ur7fpzfp2nvn75b5bvzp...
#
#                              author_handle        author_name  \
# 0  llms.activitypub.awakari.com.ap.brid.gy               LLMs
# 1                   stonedhshi.bsky.social    Stone D.-H. Shi
# 2                 freecodecamp.bsky.social   freeCodeCamp.org
# 3                      uneek35.bsky.social         Diego Diaz
# 4                american-news.bsky.social    American Sports
# 5                          shibedrill.site           0xD0EFA6
# 6                    mathskath.bsky.social  Katherine Seaton
# 7  llms.activitypub.awakari.com.ap.brid.gy               LLMs
# 8                      786news.bsky.social           786 News
# 9                         weel.bsky.social          Coba Weel
#
#                  indexed_at                created_at  \
# 0  2025-09-15T00:12:19.505Z  2025-09-15T00:11:21.000Z
# 1  2025-09-15T00:10:13.604Z  2025-09-15T00:10:12.167Z
# 2  2025-09-15T00:01:15.003Z  2025-09-15T00:01:14.834Z
# 3  2025-09-14T23:50:24.003Z  2025-09-14T23:50:22.523Z
# 4  2025-09-14T23:47:08.813Z      2025-09-14T23:47:07Z
# 5  2025-09-14T23:42:17.103Z  2025-09-14T23:42:16.748Z
# 6  2025-09-14T23:33:14.106Z  2025-09-14T23:33:12.930Z
# 7  2025-09-14T23:11:58.407Z  2025-09-14T23:05:05.000Z
# 8  2025-09-14T23:00:43.209Z      2025-09-14T23:00:41Z
# 9  2025-09-14T22:49:14.005Z  2025-09-14T22:49:13.649Z
#
#                                                 text
# 0  How can an AI train itself if no one is tellin...
# 1  High Impact Research (2023 Paper): "AB-Amy: ma...
# 2  If you're curious about how AI systems work, t...
# 3  Machine learning can and has worked that first...
# 4  Vikings vs. Falcons props, bets, SportsLine Ma...
# 5  that said: I think I am improving a lot at the...
# 6  I am learning to use a sewing machine. Better ...
# 7  A Wild Hack to Top Google in 10 Hours Using Pe...
# 8  The Machine Ethics podcast: Autonomy AI with A...
# 9  i mean, AFAICT these tweaks are all just chang...

# %% [markdown]
# ## 5) Save your results
#
# You can keep both the raw JSON and a clean CSV for later analysis/reproducibility.

# %%
# Save the last raw response (if present) and DataFrame
import os, json

os.makedirs("outputs", exist_ok=True)

# Save a minimal raw example
raw_path = "outputs/bluesky_search_raw.json"
with open(raw_path, "w", encoding="utf-8") as f:
    json.dump(data, f, ensure_ascii=False, indent=2)

# Save the wrangled table
csv_path = "outputs/bluesky_search_results.csv"
if not df.empty:
    df.to_csv(csv_path, index=False)

raw_path, os.path.exists(csv_path)
# Out:
# ('outputs/bluesky_search_raw.json', True)

# %% [markdown]
# ## 6) Another endpoint: profile lookup
#
# Try `app.bsky.actor.getProfile` to resolve data for a handle.
#
# - **Method:** `GET`
# - **URL:** `https://public.api.bsky.app/xrpc/app.bsky.actor.getProfile`
# - **Parameter:** `actor` (handle or DID)

# %%
profile_endpoint = f"{BASE_URL}/app.bsky.actor.getProfile"
params = {"actor": "bsky.app"}  # try a known handle, or change this
r = requests.get(profile_endpoint, params=params, timeout=30)
print("Status:", r.status_code)
profile = r.json() if r.ok else {}
print(js.dumps(data, indent=2))
# Out:
# Status: 200
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 6
#       4 print("Status:", r.status_code)
#       5 profile = r.json() if r.ok else {}
# ----> 6 print(jpreview(profile))
#
# Cell In[8], line 11, in jpreview(obj, maxlen)
#      10 def jpreview(obj, maxlen=800):
# ---> 11     s = pd.io.json.dumps(obj, indent=2, ensure_ascii=False)
#      12     return (s[: maxlen] + "…") if len(s) > maxlen else s
#
# AttributeError: module 'pandas.io.json' has no attribute 'dumps'

# %% [markdown]
# ## 7) Errors, limits, and ethics
#
# - **Rate limits (429):** pause and retry modestly; don’t hammer endpoints.
# - **HTTP errors:** 400/404 (bad params or not found), 401/403 (auth issues), 5xx (server issues).
# - **Schema drift:** APIs change—defensive coding and **.get()** access help.
# - **Ethics:** Posts can be personal; be thoughtful about storing, sharing, and analyzing user-generated content. Respect terms of service and privacy norms.

# %% [markdown]
# ## 8) About authentication (optional for today)
#
# Some Bluesky endpoints require authentication using **App Passwords** and session creation. For public demos we used public endpoints. For private or write operations, consult the official docs, create an App Password (not your login password), and store credentials **securely** (e.g., in environment variables or a `.env` file, never hard-code secrets in notebooks).

# %% [markdown]
# ---
#
# ### ✅ Wrap-up
#
# - You practiced the **data loop** with real HTTP calls.
# - You learned how to read **endpoint docs**, pass parameters, and parse **JSON**.
# - You wrangled results into **pandas**, handled **pagination**, and saved outputs.
#
# *Last updated:* 2025-09-14 11:46:31
