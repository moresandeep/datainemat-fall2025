# %% [markdown]
# # APIs and Endpoints — Bluesky Edition
#
# **Course theme:** Data Loop → *Question → Acquire → Analyze → Report*
# **Today’s focus:** Calling a real data API, understanding endpoints & parameters, and wrangling the JSON response.
#
# We’ll use the **Bluesky public API** for demonstrations. You’ll learn:
#
# - How to make HTTP requests with Python’s `requests`
# - How to read endpoint **parameters** and pass them correctly
# - How to parse the **JSON response** and load it into **pandas**
# - How to handle **pagination**, **rate limits**, and **errors**
# - How to save your results and think about **ethics** & **limitations** of API data

# %% [markdown]
# ## 0. Prerequisites
#
# ```bash
# # in your environment (Anaconda prompt or terminal)
# pip install requests
# ```

# %%
import time
from typing import Dict, Any, List, Optional
import requests
import pandas as pd
import json as js

BASE_URL = "https://api.bsky.app/xrpc"

# %% [markdown]
# ## 1) Quickstart: `requests` basics
#
# - **Make a GET request:** `requests.get(url, params={...}, headers={...})`
# - **Inspect status:** `resp.status_code` (200 = OK, 429 = rate-limited, 4xx/5xx = errors)
# - **Parse JSON:** `resp.json()`
# - **Headers & auth:** often required; some public endpoints don’t need auth
#
# We’ll start with a **public search endpoint** to avoid credentials.

# %% [markdown]
# ## 2) Endpoint: `app.bsky.feed.searchPosts` (public)
#
# This endpoint lets us search recent Bluesky posts.
#
# - **Method:** `GET`
# - **URL:** `https://api.bsky.app/xrpc/app.bsky.feed.searchPosts`
# - **Key parameters:**
#   - `q`: search query string (required)
#   - `limit`: number of results to return (suggest 10–50 for demos)
#   - `cursor`: for pagination (use the `cursor` returned from a prior call)
#
# > Note: Public APIs can change. If something fails today, check the official docs and reduce the scope of parameters.

# %%
endpoint = f"{BASE_URL}/app.bsky.feed.searchPosts"
headers = {"User-Agent": "EMAT-Teaching/1.0 (+contact@example.com)"}
params = {
    "q": "data science",
    "limit": 10,  # start small for demos
}

resp = requests.get(endpoint, params=params, headers=headers, timeout=30)
print("Status:", resp.status_code)
data = resp.json() if resp.headers.get("content-type", "").startswith("application/json") else {}
print("Top-level keys:", list(data.keys()))
print(js.dumps(data, indent=2))
# Out:
# Status: 200
# Top-level keys: ['posts', 'cursor']
# {
#   "posts": [
#     {
#       "uri": "at://did:plc:4llrhdclvdlmmynkwsmg5tdc/app.bsky.feed.post/3lz23ekrhnx23",
#       "cid": "bafyreifhwc7aj2f7vzbgapseyusksannbviz74f7k5dtqwvi5vareyhqmm",
#       "author": {
#         "did": "did:plc:4llrhdclvdlmmynkwsmg5tdc",
#         "handle": "atrupar.com",
#         "displayName": "Aaron Rupar",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:4llrhdclvdlmmynkwsmg5tdc/bafkreibmhm3h6ar52pogvolisrzjdhwa2myras5vkxzj67twxn2l6pogwu@jpeg",
#         "associated": {
#           "chat": {
#             "allowIncoming": "following"
#           },
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2023-04-28T00:47:57.437Z",
#         "verification": {
#           "verifications": [
#             {
#               "issuer": "did:plc:z72i7hdynmk6r22z27h6tvur",
#               "uri": "at://did:plc:z72i7hdynmk6r22z27h6tvur/app.bsky.graph.verification/3ltpn6t4d3g2e",
#               "isValid": true,
#               "createdAt": "2025-07-11T20:02:18.825Z"
#             }
#           ],
#           "verifiedStatus": "valid",
#           "trustedVerifierStatus": "none"
#         }
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T14:48:39.585Z",
#         "embed": {
#           "$type": "app.bsky.embed.video",
#           "alt": "",
#           "aspectRatio": {
#             "height": 720,
#             "width": 1280
#           },
#           "captions": [
#             {
#               "$type": "app.bsky.embed.video#caption",
#               "file": {
#                 "$type": "blob",
#                 "ref": {
#                   "$link": "bafkreic5vj4n5yjg4ldbyb4q6sybm5elksxgqhbrclgrgid5ecymex6x4y"
#                 },
#                 "mimeType": "text/vtt",
#                 "size": 1389
#               },
#               "lang": "en"
#             }
#           ],
#           "video": {
#             "$type": "blob",
#             "ref": {
#               "$link": "bafkreieq6eliedxbrxmu56mn4dyhrbz5efqxo7qf6jinpgtoninstjyn5a"
#             },
#             "mimeType": "video/mp4",
#             "size": 6621737
#           }
#         },
#         "facets": [],
#         "langs": [
#           "en"
#         ],
#         "text": "Monarez: \"He did not have any data or science to point to. In fact, we got into an exchange where I suggested I would be open to changing childhood vaccine schedules if the evidence or science were supportive. He responded there was no science or evidence associated w/the childhood vaccine schedule\""
#       },
#       "embed": {
#         "$type": "app.bsky.embed.video#view",
#         "cid": "bafkreieq6eliedxbrxmu56mn4dyhrbz5efqxo7qf6jinpgtoninstjyn5a",
#         "playlist": "https://video.bsky.app/watch/did%3Aplc%3A4llrhdclvdlmmynkwsmg5tdc/bafkreieq6eliedxbrxmu56mn4dyhrbz5efqxo7qf6jinpgtoninstjyn5a/playlist.m3u8",
#         "thumbnail": "https://video.bsky.app/watch/did%3Aplc%3A4llrhdclvdlmmynkwsmg5tdc/bafkreieq6eliedxbrxmu56mn4dyhrbz5efqxo7qf6jinpgtoninstjyn5a/thumbnail.jpg",
#         "alt": "",
#         "aspectRatio": {
#           "height": 720,
#           "width": 1280
#         }
#       },
#       "bookmarkCount": 1,
#       "replyCount": 9,
#       "repostCount": 39,
#       "likeCount": 124,
#       "quoteCount": 2,
#       "indexedAt": "2025-09-17T14:48:40.512Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:4llrhdclvdlmmynkwsmg5tdc/app.bsky.feed.post/3lz233n4dhb2r",
#       "cid": "bafyreib4lsglh6pxwgzxg4pbxnzgvn27v5ddat2woj7wqprm7oypednnau",
#       "author": {
#         "did": "did:plc:4llrhdclvdlmmynkwsmg5tdc",
#         "handle": "atrupar.com",
#         "displayName": "Aaron Rupar",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:4llrhdclvdlmmynkwsmg5tdc/bafkreibmhm3h6ar52pogvolisrzjdhwa2myras5vkxzj67twxn2l6pogwu@jpeg",
#         "associated": {
#           "chat": {
#             "allowIncoming": "following"
#           },
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2023-04-28T00:47:57.437Z",
#         "verification": {
#           "verifications": [
#             {
#               "issuer": "did:plc:z72i7hdynmk6r22z27h6tvur",
#               "uri": "at://did:plc:z72i7hdynmk6r22z27h6tvur/app.bsky.graph.verification/3ltpn6t4d3g2e",
#               "isValid": true,
#               "createdAt": "2025-07-11T20:02:18.825Z"
#             }
#           ],
#           "verifiedStatus": "valid",
#           "trustedVerifierStatus": "none"
#         }
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T14:43:40.084Z",
#         "embed": {
#           "$type": "app.bsky.embed.video",
#           "alt": "",
#           "aspectRatio": {
#             "height": 720,
#             "width": 1280
#           },
#           "captions": [
#             {
#               "$type": "app.bsky.embed.video#caption",
#               "file": {
#                 "$type": "blob",
#                 "ref": {
#                   "$link": "bafkreicv3ooecjjwz6wkigzdvkg3firfbavdjefpl3vceieiocx6vietva"
#                 },
#                 "mimeType": "text/vtt",
#                 "size": 1118
#               },
#               "lang": "en"
#             }
#           ],
#           "video": {
#             "$type": "blob",
#             "ref": {
#               "$link": "bafkreigflkqzyycb5ngmnwjdlncgcte32nkh7zgngbtjt5pkc75gkxtm6m"
#             },
#             "mimeType": "video/mp4",
#             "size": 5296985
#           }
#         },
#         "facets": [],
#         "langs": [
#           "en"
#         ],
#         "text": "former CDC official Dr. Houry: \"I first learned that the secretary had changed our CDC covid vaccine guidance on an X social media post. CDC scientists have still not seen the scientific data or justification for this change. That is not gold standard science.\""
#       },
#       "embed": {
#         "$type": "app.bsky.embed.video#view",
#         "cid": "bafkreigflkqzyycb5ngmnwjdlncgcte32nkh7zgngbtjt5pkc75gkxtm6m",
#         "playlist": "https://video.bsky.app/watch/did%3Aplc%3A4llrhdclvdlmmynkwsmg5tdc/bafkreigflkqzyycb5ngmnwjdlncgcte32nkh7zgngbtjt5pkc75gkxtm6m/playlist.m3u8",
#         "thumbnail": "https://video.bsky.app/watch/did%3Aplc%3A4llrhdclvdlmmynkwsmg5tdc/bafkreigflkqzyycb5ngmnwjdlncgcte32nkh7zgngbtjt5pkc75gkxtm6m/thumbnail.jpg",
#         "alt": "",
#         "aspectRatio": {
#           "height": 720,
#           "width": 1280
#         }
#       },
#       "bookmarkCount": 8,
#       "replyCount": 20,
#       "repostCount": 208,
#       "likeCount": 733,
#       "quoteCount": 6,
#       "indexedAt": "2025-09-17T14:43:41.504Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:d52mcxjpsmhar5bk52bgsg3h/app.bsky.feed.post/3lz2336tlzk24",
#       "cid": "bafyreigh5ixrrqur6ku4fxc25qsgbwg55fkcoaymqsnmbme4y24hkzrbdi",
#       "author": {
#         "did": "did:plc:d52mcxjpsmhar5bk52bgsg3h",
#         "handle": "datasciencenigeria.bsky.social",
#         "displayName": "Data Science Nigeria",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:d52mcxjpsmhar5bk52bgsg3h/bafkreidryzimghrezszzxlxe4nbqtgobkvu6kabukgn5gpqkrujrakfx2y@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2024-11-28T13:39:26.144Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T14:43:20.605Z",
#         "langs": [
#           "en"
#         ],
#         "reply": {
#           "parent": {
#             "cid": "bafyreicquhldmyptxswrgluuavy5bdat7hmvwzdv2ywne34g2i4w3fyou4",
#             "uri": "at://did:plc:d52mcxjpsmhar5bk52bgsg3h/app.bsky.feed.post/3lz2332jbbc24"
#           },
#           "root": {
#             "cid": "bafyreicquhldmyptxswrgluuavy5bdat7hmvwzdv2ywne34g2i4w3fyou4",
#             "uri": "at://did:plc:d52mcxjpsmhar5bk52bgsg3h/app.bsky.feed.post/3lz2332jbbc24"
#           }
#         },
#         "text": " As an important chapter within the Data Science Nigeria (DSN) network, DSN JSTU has been actively creating opportunities for students to explore and grow in AI. \n\nHere\u2019s a glimpse of some of their recent initiatives:"
#       },
#       "bookmarkCount": 0,
#       "replyCount": 1,
#       "repostCount": 0,
#       "likeCount": 0,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T14:43:27.030Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:x7irsqqhp64woalar7obnnft/app.bsky.feed.post/3lz2326xy3s2v",
#       "cid": "bafyreiczxvuxp4xkl3zktle7suubzbmafbgcyro73hn3gq4zidjpnnbqvq",
#       "author": {
#         "did": "did:plc:x7irsqqhp64woalar7obnnft",
#         "handle": "standupforscience.bsky.social",
#         "displayName": "Stand Up for Science!",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:x7irsqqhp64woalar7obnnft/bafkreif2pzm3bsuk7vhojjumijxt5njmzei3dzkjfujse4nqm2nggbrafa@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2025-02-12T16:44:05.445Z",
#         "verification": {
#           "verifications": [
#             {
#               "issuer": "did:plc:z72i7hdynmk6r22z27h6tvur",
#               "uri": "at://did:plc:z72i7hdynmk6r22z27h6tvur/app.bsky.graph.verification/3lsgswlzmen24",
#               "isValid": true,
#               "createdAt": "2025-06-25T14:25:56.134Z"
#             }
#           ],
#           "verifiedStatus": "valid",
#           "trustedVerifierStatus": "none"
#         }
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T14:42:51.543Z",
#         "langs": [
#           "en"
#         ],
#         "reply": {
#           "parent": {
#             "cid": "bafyreih4p7dk5dfekanlastpz25pks5omml74gfg3z3fitwgw6jruyztfa",
#             "uri": "at://did:plc:x7irsqqhp64woalar7obnnft/app.bsky.feed.post/3lz2326xx4k2v"
#           },
#           "root": {
#             "cid": "bafyreiftxfp4hmme23jzroilfe5brmi6cqtybo6f3lyusfwxosa5gfjwou",
#             "uri": "at://did:plc:x7irsqqhp64woalar7obnnft/app.bsky.feed.post/3lyzxsvqv7s2y"
#           }
#         },
#         "text": "Cassidy: RFK Jr. had said that he didn't ask her to pre-approve. Was there any science supporting these reccs?\n\nM: No science. \u201cWould be open, if the evidence was supportive,\u201d but RFK said there was no science or data about the schedule."
#       },
#       "bookmarkCount": 0,
#       "replyCount": 1,
#       "repostCount": 1,
#       "likeCount": 4,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T14:42:52.159Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:5mbz5pb7xo2o5eef3xeixvgu/app.bsky.feed.post/3lz22jpz7p22g",
#       "cid": "bafyreid5ttkprmwjrerhwrr2whqshsgxumj6jkv4lviynbi353n3n4sdcy",
#       "author": {
#         "did": "did:plc:5mbz5pb7xo2o5eef3xeixvgu",
#         "handle": "sarahkarlin-smith.bsky.social",
#         "displayName": "Sarah Karlin-Smith",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:5mbz5pb7xo2o5eef3xeixvgu/bafkreiev3v7rewx77ghidjxehoqocg5q5res445x735d2ndtx6gzfkwldi@jpeg",
#         "associated": {
#           "chat": {
#             "allowIncoming": "all"
#           },
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2023-07-12T00:07:54.159Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T14:33:39.173Z",
#         "langs": [
#           "en"
#         ],
#         "reply": {
#           "parent": {
#             "cid": "bafyreihu3ewxowwlsk5azdy3vnp3w42gkydmnbkqn6nwuvclmasjfvgt3a",
#             "uri": "at://did:plc:5mbz5pb7xo2o5eef3xeixvgu/app.bsky.feed.post/3lz22eefajs2g"
#           },
#           "root": {
#             "cid": "bafyreib4jote3d3jgcjjw2dgqgmpezzxjxqdi6lyobf3wyuaaqzneavcli",
#             "uri": "at://did:plc:5mbz5pb7xo2o5eef3xeixvgu/app.bsky.feed.post/3lyzyy2sf7c2x"
#           }
#         },
#         "text": "Houry: I first learned that HHS Sec had changed CDC covid vaccine guidance on X social media posts. CDC scientists have still not seen the scientific data or justification for this change. That is not gold standard science."
#       },
#       "bookmarkCount": 0,
#       "replyCount": 1,
#       "repostCount": 5,
#       "likeCount": 9,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T14:33:39.706Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:xtrzqicesfwterpbweugpl4u/app.bsky.feed.post/3lz22j3s2pk2f",
#       "cid": "bafyreihdoeverck6v6rri3y3lebzo5faj7x22gkkwkd35ajswumathm2h4",
#       "author": {
#         "did": "did:plc:xtrzqicesfwterpbweugpl4u",
#         "handle": "altcdc.altgov.info",
#         "displayName": "Alt CDC (they/them)",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:xtrzqicesfwterpbweugpl4u/bafkreid2qlxqmwis5lcu4nvquafv6pl6q3j2amfh4fqdpazaktu4cqhfre@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2024-11-29T19:31:29.545Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T14:33:17.967Z",
#         "langs": [
#           "en"
#         ],
#         "reply": {
#           "parent": {
#             "cid": "bafyreifymbudbfzstafhvhzi5ino4xzz3nahncg4tythsqedlukmketyfu",
#             "uri": "at://did:plc:xtrzqicesfwterpbweugpl4u/app.bsky.feed.post/3lz22hmfz222f"
#           },
#           "root": {
#             "cid": "bafyreiatrqhyfznpvixmwemepbpwxoxr4h5padj37gmjugquppzf3vqt6u",
#             "uri": "at://did:plc:xtrzqicesfwterpbweugpl4u/app.bsky.feed.post/3lyzz7so5mc2f"
#           }
#         },
#         "text": "Dr Houry: Recent ACIP meetings have been secretive and presented false and fictitious data as science (paraphrase)"
#       },
#       "bookmarkCount": 1,
#       "replyCount": 0,
#       "repostCount": 2,
#       "likeCount": 14,
#       "quoteCount": 1,
#       "indexedAt": "2025-09-17T14:33:18.502Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:7migibs2fyj2psyy6lmkul3h/app.bsky.feed.post/3lz22isaw2s2g",
#       "cid": "bafyreifmvqa6q7l35jqd2k5exfbaihg3g5bjoitfnvfk4ol4o5h7lqlasq",
#       "author": {
#         "did": "did:plc:7migibs2fyj2psyy6lmkul3h",
#         "handle": "publichealthguy1.bsky.social",
#         "displayName": "public health guy",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:7migibs2fyj2psyy6lmkul3h/bafkreicppif2mdt2veempttylbhoxnv3vfrxnhzh2dyoh5e5ownn4as6me@jpeg",
#         "associated": {
#           "chat": {
#             "allowIncoming": "all"
#           },
#           "activitySubscription": {
#             "allowSubscriptions": "mutuals"
#           }
#         },
#         "labels": [
#           {
#             "src": "did:plc:7migibs2fyj2psyy6lmkul3h",
#             "uri": "at://did:plc:7migibs2fyj2psyy6lmkul3h/app.bsky.actor.profile/self",
#             "cid": "bafyreih3wviz7jto7y3rk6posytpa3gy5ilxooqlelr3kvez44x4kaii74",
#             "val": "!no-unauthenticated",
#             "cts": "1970-01-01T00:00:00.000Z"
#           }
#         ],
#         "createdAt": "2023-05-17T21:45:38.548Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T14:33:07.968Z",
#         "langs": [
#           "en"
#         ],
#         "text": "dr. houry - CDC scientists STILL have not seen the scientific data and justification for [RFK\u2019s covid vaccine recs]. \u201cthat is not gold standard science.\u201d"
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 3,
#       "likeCount": 15,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T14:33:09.503Z",
#       "labels": [],
#       "threadgate": {
#         "uri": "at://did:plc:7migibs2fyj2psyy6lmkul3h/app.bsky.feed.threadgate/3lz22isaw2s2g",
#         "cid": "bafyreid32otgzviuzca25ity23oboantvxo2l6f4zkqtbqysxt42zbzdfu",
#         "record": {
#           "$type": "app.bsky.feed.threadgate",
#           "allow": [
#             {
#               "$type": "app.bsky.feed.threadgate#mentionRule"
#             },
#             {
#               "$type": "app.bsky.feed.threadgate#followingRule"
#             },
#             {
#               "$type": "app.bsky.feed.threadgate#followerRule"
#             }
#           ],
#           "createdAt": "2025-09-17T14:33:07.973Z",
#           "hiddenReplies": [],
#           "post": "at://did:plc:7migibs2fyj2psyy6lmkul3h/app.bsky.feed.post/3lz22isaw2s2g"
#         },
#         "lists": []
#       }
#     },
#     {
#       "uri": "at://did:plc:e7gbntp2tzobn7cfi37viei3/app.bsky.feed.post/3lz22igtugc2s",
#       "cid": "bafyreibdr3bxtulsx6g7mhxgs3thyqnbpbgpbzmyijhmkaksip5ohitaza",
#       "author": {
#         "did": "did:plc:e7gbntp2tzobn7cfi37viei3",
#         "handle": "ericmgarcia.bsky.social",
#         "displayName": "Eric Michael Garcia",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:e7gbntp2tzobn7cfi37viei3/bafkreihhggtxdctdffgojonctykf6hy4b2vpwd77wdyosjbj42hjdundh4@jpeg",
#         "associated": {
#           "chat": {
#             "allowIncoming": "following"
#           },
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2023-05-09T02:06:21.664Z",
#         "verification": {
#           "verifications": [
#             {
#               "issuer": "did:plc:z72i7hdynmk6r22z27h6tvur",
#               "uri": "at://did:plc:z72i7hdynmk6r22z27h6tvur/app.bsky.graph.verification/3lynrah4uh72o",
#               "isValid": true,
#               "createdAt": "2025-09-12T17:15:26.987Z"
#             }
#           ],
#           "verifiedStatus": "valid",
#           "trustedVerifierStatus": "none"
#         }
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T14:32:56.005Z",
#         "langs": [
#           "en"
#         ],
#         "reply": {
#           "parent": {
#             "cid": "bafyreibugkuwfka3fet3deyrmkva7wdrmutmbgagtzrjs73d3ax3cvfkqq",
#             "uri": "at://did:plc:e7gbntp2tzobn7cfi37viei3/app.bsky.feed.post/3lz22gcxht22s"
#           },
#           "root": {
#             "cid": "bafyreiedkbjend6exilcjw6yrotopplnmhv5jjio23llyhisa7f2wp2aj4",
#             "uri": "at://did:plc:e7gbntp2tzobn7cfi37viei3/app.bsky.feed.post/3lyzyuopjmc2b"
#           }
#         },
#         "text": "\"Here again, the problem is not too much science, but too little. I personally had changed our CDC coded vaccine guidance on an X social media post,\" Houry says. \"CDC scientists are still not seeing science for data or justification for this change that is not gold standard science.\""
#       },
#       "bookmarkCount": 0,
#       "replyCount": 1,
#       "repostCount": 2,
#       "likeCount": 12,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T14:32:56.407Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:wswfzltqlwbzbvvz5xm7rflt/app.bsky.feed.post/3lyzzgnwbac2l",
#       "cid": "bafyreic2czz2aaylz3j2x6dnxalhms4g5fgzd4xnd4sjny2gsfqscd6wpq",
#       "author": {
#         "did": "did:plc:wswfzltqlwbzbvvz5xm7rflt",
#         "handle": "koutavi.bsky.social",
#         "displayName": "ana is tired",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:wswfzltqlwbzbvvz5xm7rflt/bafkreifeyqpokjdw6zxyckvgnbbxmmnlpyjvlxx4olhefwyik5mj7d4soq@jpeg",
#         "associated": {
#           "chat": {
#             "allowIncoming": "all"
#           },
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2023-09-25T02:40:47.652Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T14:14:02.572Z",
#         "langs": [
#           "en"
#         ],
#         "text": "covid booster and flu shot DONE. everybody get your science stabs, vaccination is probably the most lifesaving medical advancement humanity has ever come up with! don't believe the eugenicists!! believe data!!!"
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 0,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T14:14:05.214Z",
#       "labels": []
#     },
#     {
#       "uri": "at://did:plc:twtaealbpldgyur7sh4ixtee/app.bsky.feed.post/3lyzzcuula22r",
#       "cid": "bafyreiaxndboh3t76bvxbzzeem5jvf5gh4tbbgwjj7hykvzvp6euikibh4",
#       "author": {
#         "did": "did:plc:twtaealbpldgyur7sh4ixtee",
#         "handle": "daveelmore12.bsky.social",
#         "displayName": "daveelmore12",
#         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:twtaealbpldgyur7sh4ixtee/bafkreibjrzbkcdwrhbl2knd2rw2g3zfzmzfcrn34tqii3atgrxinfobc5q@jpeg",
#         "associated": {
#           "activitySubscription": {
#             "allowSubscriptions": "followers"
#           }
#         },
#         "labels": [],
#         "createdAt": "2024-11-09T17:50:21.182Z"
#       },
#       "record": {
#         "$type": "app.bsky.feed.post",
#         "createdAt": "2025-09-17T14:11:55.640Z",
#         "embed": {
#           "$type": "app.bsky.embed.record",
#           "record": {
#             "cid": "bafyreihbefru4wpvf6y6l4jwumk5auvpxxbcizq4xd6msnere26yv5xtqy",
#             "uri": "at://did:plc:xmlxpu4drzbkfno5vw4wrv4l/app.bsky.feed.post/3lyzsich44k2k"
#           }
#         },
#         "facets": [
#           {
#             "$type": "app.bsky.richtext.facet",
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#mention",
#                 "did": "did:plc:s42mqldnbhkb2p4p5qfynmum"
#               }
#             ],
#             "index": {
#               "byteEnd": 67,
#               "byteStart": 40
#             }
#           },
#           {
#             "$type": "app.bsky.richtext.facet",
#             "features": [
#               {
#                 "$type": "app.bsky.richtext.facet#mention",
#                 "did": "did:plc:vkbslctcrdhk6x2c4rbyryxy"
#               }
#             ],
#             "index": {
#               "byteEnd": 201,
#               "byteStart": 175
#             }
#           }
#         ],
#         "langs": [
#           "en"
#         ],
#         "text": "The science and data prove this and yet @cityofwinnipeg.bsky.social continues to study and delay what should be an obvious choice to lower residential speed limits to 30 kph. @safespeedswpg.bsky.social"
#       },
#       "embed": {
#         "$type": "app.bsky.embed.record#view",
#         "record": {
#           "$type": "app.bsky.embed.record#viewRecord",
#           "uri": "at://did:plc:xmlxpu4drzbkfno5vw4wrv4l/app.bsky.feed.post/3lyzsich44k2k",
#           "cid": "bafyreihbefru4wpvf6y6l4jwumk5auvpxxbcizq4xd6msnere26yv5xtqy",
#           "author": {
#             "did": "did:plc:xmlxpu4drzbkfno5vw4wrv4l",
#             "handle": "thewaroncars.bsky.social",
#             "displayName": "The War on Cars",
#             "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:xmlxpu4drzbkfno5vw4wrv4l/bafkreiacofvm5npvpt5y3rj4inx4trdf4dpkkdyw5hoixlykebcnsf2q5a@jpeg",
#             "associated": {
#               "chat": {
#                 "allowIncoming": "all"
#               },
#               "activitySubscription": {
#                 "allowSubscriptions": "followers"
#               }
#             },
#             "labels": [],
#             "createdAt": "2023-05-24T02:12:57.626Z"
#           },
#           "value": {
#             "$type": "app.bsky.feed.post",
#             "createdAt": "2025-09-17T12:09:41.459Z",
#             "embed": {
#               "$type": "app.bsky.embed.external",
#               "external": {
#                 "description": "Figures show a 25% reduction in the number of injuries on Wales' roads in the past 18 months.",
#                 "thumb": {
#                   "$type": "blob",
#                   "ref": {
#                     "$link": "bafkreihzph2kuhjhfimwihy5gd7g22ts3h2ug6by6zuvgkxjkjqvoo2r24"
#                   },
#                   "mimeType": "image/jpeg",
#                   "size": 755305
#                 },
#                 "title": "Nearly 900 fewer people injured since 20mph introduction in Wales",
#                 "uri": "https://www.bbc.com/news/articles/cm286pyjml7o"
#               }
#             },
#             "langs": [
#               "en"
#             ],
#             "text": "Slower speeds save lives: \"...there were 2,638 people injured, including deaths, on low-speed roads in the most recent 18 months, compared with 3,520 injuries between April 2022 and September 2023, a reduction of 25%.\""
#           },
#           "labels": [],
#           "likeCount": 123,
#           "replyCount": 1,
#           "repostCount": 28,
#           "quoteCount": 6,
#           "indexedAt": "2025-09-17T12:09:43.303Z",
#           "embeds": [
#             {
#               "$type": "app.bsky.embed.external#view",
#               "external": {
#                 "uri": "https://www.bbc.com/news/articles/cm286pyjml7o",
#                 "title": "Nearly 900 fewer people injured since 20mph introduction in Wales",
#                 "description": "Figures show a 25% reduction in the number of injuries on Wales' roads in the past 18 months.",
#                 "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:xmlxpu4drzbkfno5vw4wrv4l/bafkreihzph2kuhjhfimwihy5gd7g22ts3h2ug6by6zuvgkxjkjqvoo2r24@jpeg"
#               }
#             }
#           ]
#         }
#       },
#       "bookmarkCount": 0,
#       "replyCount": 0,
#       "repostCount": 0,
#       "likeCount": 2,
#       "quoteCount": 0,
#       "indexedAt": "2025-09-17T14:11:57.804Z",
#       "labels": []
#     }
#   ],
#   "cursor": "10"
# }

# %%
rows = []
for post in data["posts"]:
    rows.append({
        "Author": post["author"].get("displayName"),
        "Text": post["record"].get("text"),
        "Likes": post.get("likeCount", 0),
        "Timestamp": post["record"].get("createdAt")
    })

# %% [markdown]
# ### Interpreting the response
#
# Typical top-level fields you may see:
#
# - `posts`: a list of post objects (each with author and record info)
# - `cursor`: a string to request the **next page**
#
# Each post commonly includes:
# - `uri`, `cid`: identifiers
# - `author`: nested object (e.g., `displayName`, `handle`, `did`)
# - `record`: nested object with `text` and timestamps (`createdAt`)
# - `indexedAt`: when Bluesky indexed the post
#
# Let’s normalize the JSON into a tidy table.

# %%
# Create DataFrame
df = pd.DataFrame(rows, columns=["Author", "Text", "Likes", "Timestamp"])

# Show as table in Jupyter
df.head()
# Out:
#                   Author                                               Text  \
# 0            Aaron Rupar  former CDC official Dr. Houry: "I first learne...
# 1   Data Science Nigeria   As an important chapter within the Data Scien...
# 2  Stand Up for Science!  Cassidy: RFK Jr. had said that he didn't ask h...
#
#    Likes                 Timestamp
# 0    415  2025-09-17T14:43:40.084Z
# 1      0  2025-09-17T14:43:20.605Z
# 2      4  2025-09-17T14:42:51.543Z

# %% [markdown]
# # Authentication
